# %% [markdown]
# # Aplikasi Image-Scraper
# #### Scrape images from the web
#
# -----

# %% [markdown]
# Enter the list of keywords in the cell below

# %%
# %%writefile keywords.txt
# Rumah adat gadang sumatera
# Rumah adat gadang
# gadang sumatera
# Out:
# Overwriting keywords.txt

# %%
# Search engine to use while scraping the images. 
search_engine = "all" # [google, bing, yahoo, duckduckgo, all]

# Number of images per keyword. All images are downloaded when set to None
num_images = None

# Add a prefix and/or suffix to all the keywords
prefix = None
suffix = None

# Threshold for removing similar images
similarity_threshold = 0.98

# Output directory to store the scraped images
out_dir = "images"

# %% [markdown]
# -----

# %%
# !pip install imagehash
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting imagehash
#   Downloading ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
#      |████████████████████████████████| 296 kB 4.8 MB/s
# Requirement already satisfied: pillow in /usr/local/lib/python3.8/dist-packages (from imagehash) (7.1.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from imagehash) (1.7.3)
# Requirement already satisfied: PyWavelets in /usr/local/lib/python3.8/dist-packages (from imagehash) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from imagehash) (1.21.6)
# Installing collected packages: imagehash
# Successfully installed imagehash-4.3.1

# %%
import os, platform, sys, argparse, glob
import time
import base64
import hashlib
from io import BytesIO
from html.parser import HTMLParser
from urllib.parse import quote, unquote

from tqdm import tqdm
import urllib3
import PIL.Image as Image

import numpy as np
import imagehash

# %%
import warnings
warnings.filterwarnings('ignore', message='Unverified HTTPS request')

# %%
# !pip install selenium
from selenium import webdriver
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: selenium in /usr/local/lib/python3.8/dist-packages (4.7.2)
# Requirement already satisfied: trio~=0.17 in /usr/local/lib/python3.8/dist-packages (from selenium) (0.22.0)
# Requirement already satisfied: urllib3[socks]~=1.26 in /usr/local/lib/python3.8/dist-packages (from selenium) (1.26.13)
# Requirement already satisfied: certifi>=2021.10.8 in /usr/local/lib/python3.8/dist-packages (from selenium) (2022.9.24)
# Requirement already satisfied: trio-websocket~=0.9 in /usr/local/lib/python3.8/dist-packages (from selenium) (0.9.2)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in /usr/local/lib/python3.8/dist-packages (from trio~=0.17->selenium) (1.0.4)
# Requirement already satisfied: idna in /usr/local/lib/python3.8/dist-packages (from trio~=0.17->selenium) (2.10)
# Requirement already satisfied: async-generator>=1.9 in /usr/local/lib/python3.8/dist-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.8/dist-packages (from trio~=0.17->selenium) (22.1.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.8/dist-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.8/dist-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: outcome in /usr/local/lib/python3.8/dist-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: wsproto>=0.14 in /usr/local/lib/python3.8/dist-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.8/dist-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /usr/local/lib/python3.8/dist-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %%
# !apt-get update 
# !apt install chromium-chromedriver -y
# Out:
# Get:1 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:3 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease [1,581 B]
# Hit:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:6 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:7 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:9 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:10 http://security.ubuntu.com/ubuntu bionic-security/multiverse amd64 Packages [22.9 kB]
# Get:11 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [3,094 kB]
# Get:12 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages [1,056 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [83.3 kB]
# Hit:14 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Get:15 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [1,307 kB]
# Get:16 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,567 kB]
# Get:17 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease [21.3 kB]
# Get:19 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main Sources [2,234 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic-updates/multiverse amd64 Packages [30.0 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [3,519 kB]
# Get:22 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 Packages [1,143 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,342 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [1,347 kB]
# Get:25 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 Packages [40.8 kB]
# Fetched 18.0 MB in 6s (2,918 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   chromium-browser chromium-browser-l10n chromium-codecs-ffmpeg-extra
# Suggested packages:
#   webaccounts-chromium-extension unity-chromium-extension
# The following NEW packages will be installed:
#   chromium-browser chromium-browser-l10n chromium-chromedriver
#   chromium-codecs-ffmpeg-extra
# 0 upgraded, 4 newly installed, 0 to remove and 19 not upgraded.
# Need to get 95.1 MB of archives.
# After this operation, 319 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-codecs-ffmpeg-extra amd64 107.0.5304.87-0ubuntu11.18.04.1 [1,158 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-browser amd64 107.0.5304.87-0ubuntu11.18.04.1 [83.1 MB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-browser-l10n all 107.0.5304.87-0ubuntu11.18.04.1 [5,260 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-chromedriver amd64 107.0.5304.87-0ubuntu11.18.04.1 [5,570 kB]
# Fetched 95.1 MB in 5s (20.2 MB/s)
# Selecting previously unselected package chromium-codecs-ffmpeg-extra.
# (Reading database ... 124015 files and directories currently installed.)
# Preparing to unpack .../chromium-codecs-ffmpeg-extra_107.0.5304.87-0ubuntu11.18.04.1_amd64.deb ...
# Unpacking chromium-codecs-ffmpeg-extra (107.0.5304.87-0ubuntu11.18.04.1) ...
# Selecting previously unselected package chromium-browser.
# Preparing to unpack .../chromium-browser_107.0.5304.87-0ubuntu11.18.04.1_amd64.deb ...
# Unpacking chromium-browser (107.0.5304.87-0ubuntu11.18.04.1) ...
# Selecting previously unselected package chromium-browser-l10n.
# Preparing to unpack .../chromium-browser-l10n_107.0.5304.87-0ubuntu11.18.04.1_all.deb ...
# Unpacking chromium-browser-l10n (107.0.5304.87-0ubuntu11.18.04.1) ...
# Selecting previously unselected package chromium-chromedriver.
# Preparing to unpack .../chromium-chromedriver_107.0.5304.87-0ubuntu11.18.04.1_amd64.deb ...
# Unpacking chromium-chromedriver (107.0.5304.87-0ubuntu11.18.04.1) ...
# Setting up chromium-codecs-ffmpeg-extra (107.0.5304.87-0ubuntu11.18.04.1) ...
# Setting up chromium-browser (107.0.5304.87-0ubuntu11.18.04.1) ...
# update-alternatives: using /usr/bin/chromium-browser to provide /usr/bin/x-www-browser (x-www-browser) in auto mode
# update-alternatives: using /usr/bin/chromium-browser to provide /usr/bin/gnome-www-browser (gnome-www-browser) in auto mode
# Setting up chromium-chromedriver (107.0.5304.87-0ubuntu11.18.04.1) ...
# Setting up chromium-browser-l10n (107.0.5304.87-0ubuntu11.18.04.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.6) ...

# %%
sys.path.insert(0,'/usr/lib/chromium-browser/chromedriver')

# %%
# Instantiate and connect to the chrome driver 
def setup_browser():
	options = webdriver.ChromeOptions()
	options.add_argument('--headless')
	options.add_argument('--no-sandbox')
	options.add_argument('--disable-dev-shm-usage')
	browser = webdriver.Chrome('chromedriver', options=options)

	return browser

# %%
# Get the SHA-256 hash of a file
def sha256(fname, size=4096):
 
	sha256_hash = hashlib.sha256()
	with open(fname, 'rb') as f:
		for byte_block in iter(lambda: f.read(4096), b""):
			sha256_hash.update(byte_block)
		
	return sha256_hash.hexdigest()

# Find difference between files using SHA-256 and remove duplicates
def remove_duplicate_images(directory):
	print("\nChecking for duplicate images by comparing SHA-256 hash")
	flag = False

	file_list = glob.glob(f"{directory}/*.png")

	unique = []
	for file in file_list:
		filehash = sha256(file)

		if filehash not in unique:
			unique.append(filehash)
		else:
			print(f"Removing duplicate image: {file}")
			os.remove(file)	
			flag = True
			
	if flag == False:
		print("No duplicate images found")


# Get a combined perceptual hashs of a image
def get_perceptual_hash(img_path):
	img = Image.open(img_path)

	hashes = [
		imagehash.average_hash,
		imagehash.phash,
		imagehash.dhash,
		imagehash.whash,
	]

	combined_hash = np.array([h(img).hash for h in hashes]).flatten()
	combined_hash = np.where(combined_hash==True, 1, 0)

	return combined_hash

# Compare combined perceptual hashs of two images
def compare_hash(hash1, hash2):
	assert len(hash1) == len(hash2)

	count = 0
	for i in range(len(hash1)):
		if hash1[i] == hash2[i]:
			count +=1

	return count/len(hash1)

# Remove similar images using perceptual hashs
def remove_similar_images(directory, similarity_threshold=0.98):
	print("\nChecking for similar images")
	file_list = glob.glob(f"{directory}/*.png")

	found = False
	unique = []
	for file in file_list:
		filehash = get_perceptual_hash(file)

		flag = False
		for each in unique:
			similarity = compare_hash(each, filehash)

			if similarity >= similarity_threshold:
				flag = True
				found = True
				break

		if flag:
			print(f"Removing similar image: {file}")
			os.remove(file)
		else:
			unique.append(filehash)

	if not found:
		print("No similar images found")

# %%
# Class to extract the value of specific HTML tag attribute
class Extractor(HTMLParser):
  src = []
  tag_attr = None
  def handle_starttag(self, tag, attrs):
    if tag == "img":
      for each in attrs:
        if each[0] == self.tag_attr:
          self.src.append(each[1])

# Create output directory if it does not exist
def create_output_directory(keyword, out_dir=None):
	if out_dir == None:
		os.makedirs(keyword, exist_ok=True)		
	else:
		os.makedirs(out_dir, exist_ok=True)
		os.makedirs(f"{out_dir}/{keyword}", exist_ok=True)

def add_prefix_suffix(keyword, prefix=None, suffix=None):
	if prefix != None:
		keyword = prefix + " " + keyword

	if suffix != None:
		keyword = keyword + " " + suffix
	
	return keyword

def filter_src_format(src_list):
	filtered = []

	for each_src in src_list:
		if ".png" in each_src or ".jpg" in each_src or ".jpeg" in each_src:
			filtered.append(each_src)
		elif "/png" in each_src or "/jpg" in each_src or "/jpeg" in each_src:
			filtered.append(each_src)
		elif "https:" in each_src:
			filtered.append(each_src)
		else:
			continue

	return filtered


def get_img_data(url, src):
	if "https:" in src or "www." in src:
		response = http.request('GET', src)
		img_data = BytesIO(response.data)

	elif src.endswith(".png") or src.endswith(".jpg"):
		base_url = urlparse(url).netloc
		src = base_url + src

		response = http.request('GET', src)
		img_data = BytesIO(response.data)

	else:
		src = src.split(',')[-1]
		img_data = base64.b64decode(src)
		img_data = BytesIO(img_data)

	return img_data

# Search for the specified keyword using the specified search engine, load the url on chrome 
# using chromedriver, extract certain attribute values and then collect the images
def scrape_images_search_engine(keyword, search_engine, output_directory, num_images=None):		
	print(f"\nSearch engine: {search_engine}")

	search_engine_urls = {
		"google" : f"https://www.google.com/search?tbm=isch&q={quote(keyword)}",
		"bing" : f"https://www.bing.com/images/search?q={quote(keyword)}",
		"yahoo" : f"https://images.search.yahoo.com/search/images?p={quote(keyword)}",
		"duckduckgo": f"https://duckduckgo.com/?q={quote(keyword)}&iax=images&ia=images"
	}
	url = search_engine_urls[search_engine]
	print(f"URL: {url}")

	browser.get(url)
	time.sleep(2)

	scroll_count = {"google": 3, "bing": 3, "yahoo": 1, "duckduckgo": 5}
	for _ in range(scroll_count[search_engine]):
		browser.execute_script("window.scrollTo(0,document.body.scrollHeight)")
		browser.execute_script("window.scrollTo(0,document.body.scrollHeight)")
		time.sleep(2)

	extractor.src = []

	if search_engine == "google":
		extractor.tag_attr = "data-src"
		extractor.feed(browser.page_source)
		
		extractor.tag_attr = "src"
		extractor.feed(browser.page_source)

	elif search_engine == "bing":
		extractor.tag_attr = "src"
		extractor.feed(browser.page_source)

		extractor.src = list(map(lambda x: x.split('?w')[0], extractor.src))
		extractor.src = list(set(extractor.src))

		filtered = []
		for each in extractor.src:
			if "OIP" in each:
				filtered.append(each)

		extractor.src = filtered	
		
	elif search_engine == "yahoo":
		extractor.tag_attr = "src"
		extractor.feed(browser.page_source)

		extractor.src = list(map(lambda x: x.split('&')[0], extractor.src))
		extractor.src = list(set(extractor.src))

	elif search_engine == "duckduckgo":
		extractor.tag_attr = "src"
		extractor.feed(browser.page_source)

		extractor.src = list(map(lambda x: unquote(x.split('?')[-1][2:]), extractor.src))

	extractor.src = filter_src_format(extractor.src)
	len_src = len(extractor.src)
	print(f"Number of images found: {len_src}")

	if num_images != None:
		src_list = extractor.src[:num_images]
	else:
		src_list = extractor.src

	count = 0
	for each_src in tqdm(src_list):
		try:
			img_data = get_img_data(url, each_src)

			image = Image.open(img_data).convert("RGBA")
			image.save(f"{output_directory}/{search_engine[0]}-{count+1}.png")
				
			count+=1

		except:
			print(f"Something went wrong while scraping the image at URL:\n{each_src}")

	if num_images != None:
		print(f"Downloaded {count}/{num_images} images")
	else:
		print(f"Downloaded {count}/{len_src} images")

# %%
browser = setup_browser()
extractor = Extractor()
http = urllib3.PoolManager()

if search_engine not in ['google', 'bing', 'yahoo', 'duckduckgo', 'all']:
  raise Exception("Search engine needs to be one of the following: google, bing, yahoo, duckduckgo or all")

if num_images != None:
  num_images = [num_images // 4 + (1 if x < num_images % 4 else 0)  for x in range (4)]

with open("keywords.txt", 'r') as infile:
  keywords = infile.read().splitlines()

  for each in keywords:
    if each != "":
      print('\n' + '-' * 100)
      
      keyword = add_prefix_suffix(each, prefix=prefix, suffix=suffix).strip()
      print(f"Keyword: {keyword}")

      create_output_directory(keyword, out_dir)
      output_directory = keyword if out_dir == None else f"{out_dir}/{keyword}"

      if search_engine != "all":
        scrape_images_search_engine(keyword=keyword, search_engine=search_engine, output_directory=output_directory, num_images=num_images)
      else:
        if num_images != None:
          for i, each_se in enumerate(['google', 'bing', 'yahoo', 'duckduckgo']):
            scrape_images_search_engine(keyword=keyword, search_engine=each_se, output_directory=output_directory, num_images=num_images[i])
        else:
          for each_se in ['google', 'bing', 'yahoo', 'duckduckgo']:
            scrape_images_search_engine(keyword=keyword, search_engine=each_se, output_directory=output_directory, num_images=num_images)

      remove_duplicate_images(output_directory)
      remove_similar_images(output_directory, similarity_threshold)
      print('-' * 100)
    
      time.sleep(2)

browser.quit()
# Out:
# ----------------------------------------------------------------------------------------------------
# Keyword: Rumah adat gadang sumatera
#
# Search engine: google
# URL: https://www.google.com/search?tbm=isch&q=Rumah%20adat%20gadang%20sumatera
# Number of images found: 857
#  16%|█▌        | 136/857 [00:05<00:29, 24.60it/s]
# Something went wrong while scraping the image at URL:
# https://encrypted-tbn2.gstatic.com/faviconV2?url=https://smtp.tni.mil.id&client=VFE&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL&nfrp=2
#  25%|██▌       | 218/857 [00:08<00:21, 30.08it/s]
# Something went wrong while scraping the image at URL:
# https://encrypted-tbn2.gstatic.com/faviconV2?url=https://jelajahsumbar.com&client=VFE&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL&nfrp=2
#  41%|████      | 353/857 [00:13<00:20, 24.15it/s]
# Something went wrong while scraping the image at URL:
# https://encrypted-tbn2.gstatic.com/faviconV2?url=https://daftarkulinerindonesia.web.id&client=VFE&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL&nfrp=2
#  46%|████▌     | 392/857 [00:15<00:21, 21.84it/s]
# Something went wrong while scraping the image at URL:
# https://encrypted-tbn2.gstatic.com/faviconV2?url=https://tribunsumbar.com&client=VFE&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL&nfrp=2
# Something went wrong while scraping the image at URL:
# https://encrypted-tbn2.gstatic.com/faviconV2?url=https://ceritapadang.com&client=VFE&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL&nfrp=2
#  48%|████▊     | 408/857 [00:16<00:24, 18.10it/s]
# Something went wrong while scraping the image at URL:
# https://encrypted-tbn2.gstatic.com/faviconV2?url=https://mondasiregar.com&client=VFE&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL&nfrp=2
#  52%|█████▏    | 447/857 [00:17<00:12, 34.03it/s]
# Something went wrong while scraping the image at URL:
# https://encrypted-tbn2.gstatic.com/faviconV2?url=https://smtp.tni.mil.id&client=VFE&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL&nfrp=2
#  60%|█████▉    | 511/857 [00:19<00:13, 26.29it/s]
# Something went wrong while scraping the image at URL:
# https://encrypted-tbn2.gstatic.com/faviconV2?url=https://ceritadongenganak.com&client=VFE&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL&nfrp=2
#  71%|███████   | 606/857 [00:22<00:03, 63.41it/s]
# Something went wrong while scraping the image at URL:
# https://fonts.gstatic.com/s/i/productlogos/lens_camera/v1/192px.svg
# 100%|██████████| 857/857 [00:26<00:00, 32.62it/s]
# Downloaded 848/857 images
#
# Search engine: bing
# URL: https://www.bing.com/images/search?q=Rumah%20adat%20gadang%20sumatera
# Number of images found: 10
# 100%|██████████| 10/10 [00:01<00:00,  9.42it/s]
# Downloaded 10/10 images
#
# Search engine: yahoo
# URL: https://images.search.yahoo.com/search/images?p=Rumah%20adat%20gadang%20sumatera
# Number of images found: 54
#   6%|▌         | 3/54 [00:00<00:05,  9.74it/s]
# Something went wrong while scraping the image at URL:
# https://s.yimg.com/fz/api/res/1.2/yZZanxayPzp_qswouslOqg--~C/YXBwaWQ9c3JjaGRkO2ZpPWZpbGw7aD05Njt3PTk2/https://tse4.mm.bing.net/th?q=Rumah+Adat+Indonesia
# Something went wrong while scraping the image at URL:
# https://s.yimg.com/fz/api/res/1.2/cEXeETcLx0eavbIYqoEFeA--~C/YXBwaWQ9c3JjaGRkO2ZpPWZpbGw7aD05Njt3PTk2/https://tse3.mm.bing.net/th?q=Menggambar+Rumah+Adat
# Something went wrong while scraping the image at URL:
# https://s.yimg.com/fz/api/res/1.2/YZ_SkjMi74Dt3FEt1Q08sQ--~C/YXBwaWQ9c3JjaGRkO2ZpPWZpbGw7aD05Njt3PTk2/https://tse3.mm.bing.net/th?q=Rumah+Joglo
#  17%|█▋        | 9/54 [00:00<00:03, 12.28it/s]
# Something went wrong while scraping the image at URL:
# https://s.yimg.com/fz/api/res/1.2/FEVVFL4AcXH4tZlY_GatRA--~C/YXBwaWQ9c3JjaGRkO2ZpPWZpbGw7aD05Njt3PTk2/https://tse1.mm.bing.net/th?q=Rumah+Batak
# Something went wrong while scraping the image at URL:
# https://s.yimg.com/fz/api/res/1.2/XOpQx04O0F7ry8fDsS7uHQ--~C/YXBwaWQ9c3JjaGRkO2ZpPWZpbGw7aD05Njt3PTk2/https://tse2.mm.bing.net/th?q=Rumah+Adat+Sumbar
#  28%|██▊       | 15/54 [00:01<00:03, 10.35it/s]
# Something went wrong while scraping the image at URL:
# https://s.yimg.com/fz/api/res/1.2/oFHhxBRzNowVh91jb2SuGA--~C/YXBwaWQ9c3JjaGRkO2ZpPWZpbGw7aD05Njt3PTk2/https://tse2.mm.bing.net/th?q=Rumah+Bolon
#  41%|████      | 22/54 [00:02<00:03, 10.57it/s]
# Something went wrong while scraping the image at URL:
# https://s.yimg.com/fz/api/res/1.2/80bFzuy2SRBRL3ZDfzXvrQ--~C/YXBwaWQ9c3JjaGRkO2ZpPWZpbGw7aD05Njt3PTk2/https://tse3.mm.bing.net/th?q=Rumah+Adat+Di+Indonesia
# Something went wrong while scraping the image at URL:
# https://s.yimg.com/fz/api/res/1.2/SnMB2nhL7m0j4cUlg8ldUg--~C/YXBwaWQ9c3JjaGRkO2ZpPWZpbGw7aD05Njt3PTk2/https://tse2.mm.bing.net/th?q=Foto+Rumah+Adat
#  52%|█████▏    | 28/54 [00:02<00:02, 11.04it/s]
# Something went wrong while scraping the image at URL:
# https://s.yimg.com/fz/api/res/1.2/UT.psiRYHR_N72f7ZkKung--~C/YXBwaWQ9c3JjaGRkO2ZpPWZpbGw7aD05Njt3PTk2/https://tse2.mm.bing.net/th?q=Rumah+Minangkabau
#  65%|██████▍   | 35/54 [00:03<00:01, 10.64it/s]
# Something went wrong while scraping the image at URL:
# https://s.yimg.com/fz/api/res/1.2/JU53enOmDRKhJBZxQ82nCA--~C/YXBwaWQ9c3JjaGRkO2ZpPWZpbGw7aD05Njt3PTk2/https://tse4.mm.bing.net/th?q=Rumah+Adat+Betawi
# Something went wrong while scraping the image at URL:
# https://s.yimg.com/fz/api/res/1.2/lEbT.SL0ksRYG2u_pJwm.w--~C/YXBwaWQ9c3JjaGRkO2ZpPWZpbGw7aD05Njt3PTk2/https://tse4.mm.bing.net/th?q=Rumah+Adat+Sumatera
#  72%|███████▏  | 39/54 [00:03<00:01, 11.24it/s]
# Something went wrong while scraping the image at URL:
# https://s.yimg.com/fz/api/res/1.2/g3mDQStBcRxHXlx_TS4Jkg--~C/YXBwaWQ9c3JjaGRkO2ZpPWZpbGw7aD05Njt3PTk2/https://tse3.mm.bing.net/th?q=Rumah+Padang
# Something went wrong while scraping the image at URL:
# https://s.yimg.com/fz/api/res/1.2/dFOHqlXM0wS4xvUJ6.eVDA--~C/YXBwaWQ9c3JjaGRkO2ZpPWZpbGw7aD05Njt3PTk2/https://tse4.mm.bing.net/th?q=Rumah+Minang
#  80%|███████▉  | 43/54 [00:04<00:01, 10.67it/s]
# Something went wrong while scraping the image at URL:
# https://s.yimg.com/fz/api/res/1.2/SxYp42Fk5iRjRhRQPTdMOg--~C/YXBwaWQ9c3JjaGRkO2ZpPWZpbGw7aD05Njt3PTk2/https://tse2.mm.bing.net/th?q=Gambar+Rumah+Gadang
#  83%|████████▎ | 45/54 [00:04<00:00, 10.40it/s]
# Something went wrong while scraping the image at URL:
# https://s.yimg.com/fz/api/res/1.2/_FMDhtd.ztnyTpzIhT4rig--~C/YXBwaWQ9c3JjaGRkO2ZpPWZpbGw7aD05Njt3PTk2/https://tse2.mm.bing.net/th?q=Rumah+Adat+Yogyakarta
# 100%|██████████| 54/54 [00:05<00:00, 10.10it/s]
# Downloaded 39/54 images
#
# Search engine: duckduckgo
# URL: https://duckduckgo.com/?q=Rumah%20adat%20gadang%20sumatera&iax=images&ia=images
# Number of images found: 485
# 100%|██████████| 485/485 [00:53<00:00,  9.13it/s]
# Downloaded 485/485 images
#
# Checking for duplicate images by comparing SHA-256 hash
# Removing duplicate image: images/Rumah adat gadang sumatera/g-624.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-116.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-543.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-641.png
# Removing duplicate image: images/Rumah adat gadang sumatera/d-47.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-568.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-180.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-459.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-218.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-537.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-31.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-386.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-795.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-740.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-380.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-738.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-114.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-353.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-564.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-574.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-77.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-372.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-787.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-840.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-511.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-322.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-441.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-36.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-253.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-690.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-311.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-133.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-33.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-429.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-8.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-776.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-271.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-374.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-29.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-423.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-6.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-576.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-144.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-79.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-344.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-505.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-168.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-544.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-680.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-359.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-517.png
# Removing duplicate image: images/Rumah adat gadang sumatera/y-26.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-443.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-285.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-581.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-138.png
# Removing duplicate image: images/Rumah adat gadang sumatera/b-6.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-477.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-610.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-558.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-189.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-780.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-85.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-25.png
# Removing duplicate image: images/Rumah adat gadang sumatera/y-36.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-618.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-126.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-659.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-112.png
# Removing duplicate image: images/Rumah adat gadang sumatera/b-4.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-281.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-496.png
# Removing duplicate image: images/Rumah adat gadang sumatera/d-12.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-582.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-643.png
# Removing duplicate image: images/Rumah adat gadang sumatera/d-275.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-176.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-815.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-445.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-195.png
# Removing duplicate image: images/Rumah adat gadang sumatera/d-343.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-241.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-600.png
# Removing duplicate image: images/Rumah adat gadang sumatera/d-83.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-34.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-2.png
# Removing duplicate image: images/Rumah adat gadang sumatera/y-2.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-719.png
# Removing duplicate image: images/Rumah adat gadang sumatera/d-91.png
# Removing duplicate image: images/Rumah adat gadang sumatera/b-2.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-509.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-809.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-398.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-817.png
# Removing duplicate image: images/Rumah adat gadang sumatera/d-6.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-425.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-191.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-57.png
# Removing duplicate image: images/Rumah adat gadang sumatera/y-33.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-182.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-150.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-355.png
# Removing duplicate image: images/Rumah adat gadang sumatera/d-50.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-711.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-778.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-494.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-602.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-152.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-838.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-539.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-251.png
# Removing duplicate image: images/Rumah adat gadang sumatera/b-10.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-604.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-396.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-688.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-554.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-485.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-415.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-585.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-755.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-158.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-48.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-715.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-245.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-705.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-769.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-40.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-628.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-38.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-403.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-542.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-59.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-361.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-825.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-726.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-649.png
# Removing duplicate image: images/Rumah adat gadang sumatera/y-24.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-591.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-638.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-632.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-598.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-407.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-729.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-455.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-265.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-299.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-753.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-620.png
# Removing duplicate image: images/Rumah adat gadang sumatera/y-32.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-692.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-128.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-531.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-209.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-750.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-146.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-492.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-277.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-676.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-110.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-529.png
# Removing duplicate image: images/Rumah adat gadang sumatera/y-22.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-332.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-232.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-69.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-19.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-324.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-214.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-836.png
# Removing duplicate image: images/Rumah adat gadang sumatera/d-102.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-807.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-237.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-461.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-736.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-833.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-230.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-170.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-519.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-89.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-46.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-54.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-614.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-535.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-606.png
# Removing duplicate image: images/Rumah adat gadang sumatera/y-11.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-491.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-475.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-216.png
# Removing duplicate image: images/Rumah adat gadang sumatera/d-40.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-503.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-307.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-612.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-761.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-212.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-765.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-548.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-160.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-442.png
# Removing duplicate image: images/Rumah adat gadang sumatera/d-114.png
# Removing duplicate image: images/Rumah adat gadang sumatera/y-6.png
# Removing duplicate image: images/Rumah adat gadang sumatera/d-95.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-120.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-226.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-713.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-172.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-413.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-130.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-566.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-75.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-622.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-13.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-309.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-122.png
# Removing duplicate image: images/Rumah adat gadang sumatera/d-61.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-21.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-651.png
# Removing duplicate image: images/Rumah adat gadang sumatera/y-9.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-166.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-483.png
# Removing duplicate image: images/Rumah adat gadang sumatera/d-30.png
# Removing duplicate image: images/Rumah adat gadang sumatera/g-220.png
#
# Checking for similar images
# Removing similar image: images/Rumah adat gadang sumatera/g-779.png
# Removing similar image: images/Rumah adat gadang sumatera/d-194.png
# Removing similar image: images/Rumah adat gadang sumatera/d-98.png
# Removing similar image: images/Rumah adat gadang sumatera/d-39.png
# Removing similar image: images/Rumah adat gadang sumatera/d-51.png
# Removing similar image: images/Rumah adat gadang sumatera/g-619.png
# Removing similar image: images/Rumah adat gadang sumatera/g-607.png
# Removing similar image: images/Rumah adat gadang sumatera/d-268.png
# Removing similar image: images/Rumah adat gadang sumatera/d-111.png
# Removing similar image: images/Rumah adat gadang sumatera/d-76.png
# Removing similar image: images/Rumah adat gadang sumatera/d-85.png
# Removing similar image: images/Rumah adat gadang sumatera/d-299.png
# Removing similar image: images/Rumah adat gadang sumatera/d-28.png
# Removing similar image: images/Rumah adat gadang sumatera/d-26.png
# Removing similar image: images/Rumah adat gadang sumatera/g-94.png
# Removing similar image: images/Rumah adat gadang sumatera/d-36.png
# Removing similar image: images/Rumah adat gadang sumatera/d-84.png
# Removing similar image: images/Rumah adat gadang sumatera/d-161.png
# Removing similar image: images/Rumah adat gadang sumatera/d-337.png
# Removing similar image: images/Rumah adat gadang sumatera/d-368.png
# Removing similar image: images/Rumah adat gadang sumatera/g-760.png
# Removing similar image: images/Rumah adat gadang sumatera/d-438.png
# Removing similar image: images/Rumah adat gadang sumatera/d-17.png
# Removing similar image: images/Rumah adat gadang sumatera/d-219.png
# Removing similar image: images/Rumah adat gadang sumatera/d-74.png
# Removing similar image: images/Rumah adat gadang sumatera/d-13.png
# Removing similar image: images/Rumah adat gadang sumatera/d-305.png
# Removing similar image: images/Rumah adat gadang sumatera/g-284.png
# Removing similar image: images/Rumah adat gadang sumatera/d-262.png
# Removing similar image: images/Rumah adat gadang sumatera/d-29.png
# Removing similar image: images/Rumah adat gadang sumatera/d-58.png
# Removing similar image: images/Rumah adat gadang sumatera/y-3.png
# Removing similar image: images/Rumah adat gadang sumatera/g-593.png
# Removing similar image: images/Rumah adat gadang sumatera/d-15.png
# Removing similar image: images/Rumah adat gadang sumatera/y-25.png
# Removing similar image: images/Rumah adat gadang sumatera/d-144.png
# Removing similar image: images/Rumah adat gadang sumatera/d-332.png
# Removing similar image: images/Rumah adat gadang sumatera/d-100.png
# Removing similar image: images/Rumah adat gadang sumatera/d-117.png
# Removing similar image: images/Rumah adat gadang sumatera/y-16.png
# Removing similar image: images/Rumah adat gadang sumatera/d-16.png
# Removing similar image: images/Rumah adat gadang sumatera/d-2.png
# Removing similar image: images/Rumah adat gadang sumatera/d-267.png
# Removing similar image: images/Rumah adat gadang sumatera/d-48.png
# Removing similar image: images/Rumah adat gadang sumatera/d-101.png
# Removing similar image: images/Rumah adat gadang sumatera/d-282.png
# Removing similar image: images/Rumah adat gadang sumatera/g-84.png
# Removing similar image: images/Rumah adat gadang sumatera/d-148.png
# Removing similar image: images/Rumah adat gadang sumatera/d-231.png
# Removing similar image: images/Rumah adat gadang sumatera/d-276.png
# Removing similar image: images/Rumah adat gadang sumatera/d-20.png
# Removing similar image: images/Rumah adat gadang sumatera/g-198.png
# Removing similar image: images/Rumah adat gadang sumatera/g-169.png
# Removing similar image: images/Rumah adat gadang sumatera/d-46.png
# Removing similar image: images/Rumah adat gadang sumatera/g-125.png
# Removing similar image: images/Rumah adat gadang sumatera/g-248.png
# Removing similar image: images/Rumah adat gadang sumatera/g-808.png
# Removing similar image: images/Rumah adat gadang sumatera/g-822.png
# Removing similar image: images/Rumah adat gadang sumatera/y-29.png
# Removing similar image: images/Rumah adat gadang sumatera/y-30.png
# Removing similar image: images/Rumah adat gadang sumatera/d-315.png
# Removing similar image: images/Rumah adat gadang sumatera/g-145.png
# Removing similar image: images/Rumah adat gadang sumatera/d-264.png
# Removing similar image: images/Rumah adat gadang sumatera/d-306.png
# Removing similar image: images/Rumah adat gadang sumatera/d-365.png
# Removing similar image: images/Rumah adat gadang sumatera/g-171.png
# Removing similar image: images/Rumah adat gadang sumatera/d-151.png
# Removing similar image: images/Rumah adat gadang sumatera/d-166.png
# Removing similar image: images/Rumah adat gadang sumatera/d-134.png
# Removing similar image: images/Rumah adat gadang sumatera/g-695.png
# Removing similar image: images/Rumah adat gadang sumatera/g-202.png
# Removing similar image: images/Rumah adat gadang sumatera/d-150.png
# Removing similar image: images/Rumah adat gadang sumatera/g-221.png
# Removing similar image: images/Rumah adat gadang sumatera/d-236.png
# Removing similar image: images/Rumah adat gadang sumatera/d-224.png
# Removing similar image: images/Rumah adat gadang sumatera/d-411.png
# Removing similar image: images/Rumah adat gadang sumatera/d-41.png
# Removing similar image: images/Rumah adat gadang sumatera/d-21.png
# Removing similar image: images/Rumah adat gadang sumatera/d-147.png
# Removing similar image: images/Rumah adat gadang sumatera/d-3.png
# Removing similar image: images/Rumah adat gadang sumatera/d-235.png
# Removing similar image: images/Rumah adat gadang sumatera/d-291.png
# Removing similar image: images/Rumah adat gadang sumatera/d-233.png
# Removing similar image: images/Rumah adat gadang sumatera/d-201.png
# Removing similar image: images/Rumah adat gadang sumatera/g-549.png
# Removing similar image: images/Rumah adat gadang sumatera/d-4.png
# Removing similar image: images/Rumah adat gadang sumatera/g-739.png
# Removing similar image: images/Rumah adat gadang sumatera/d-56.png
# Removing similar image: images/Rumah adat gadang sumatera/g-66.png
# Removing similar image: images/Rumah adat gadang sumatera/d-124.png
# Removing similar image: images/Rumah adat gadang sumatera/g-412.png
# Removing similar image: images/Rumah adat gadang sumatera/d-230.png
# Removing similar image: images/Rumah adat gadang sumatera/d-234.png
# Removing similar image: images/Rumah adat gadang sumatera/d-126.png
# Removing similar image: images/Rumah adat gadang sumatera/g-743.png
# Removing similar image: images/Rumah adat gadang sumatera/y-19.png
# Removing similar image: images/Rumah adat gadang sumatera/d-171.png
# Removing similar image: images/Rumah adat gadang sumatera/y-4.png
# Removing similar image: images/Rumah adat gadang sumatera/d-169.png
# Removing similar image: images/Rumah adat gadang sumatera/d-324.png
# Removing similar image: images/Rumah adat gadang sumatera/g-252.png
# Removing similar image: images/Rumah adat gadang sumatera/d-140.png
# Removing similar image: images/Rumah adat gadang sumatera/g-592.png
# Removing similar image: images/Rumah adat gadang sumatera/g-274.png
# Removing similar image: images/Rumah adat gadang sumatera/d-9.png
# Removing similar image: images/Rumah adat gadang sumatera/d-49.png
# Removing similar image: images/Rumah adat gadang sumatera/g-601.png
# Removing similar image: images/Rumah adat gadang sumatera/d-115.png
# Removing similar image: images/Rumah adat gadang sumatera/d-53.png
# Removing similar image: images/Rumah adat gadang sumatera/d-86.png
# Removing similar image: images/Rumah adat gadang sumatera/g-635.png
# Removing similar image: images/Rumah adat gadang sumatera/d-24.png
# Removing similar image: images/Rumah adat gadang sumatera/d-313.png
# Removing similar image: images/Rumah adat gadang sumatera/g-131.png
# Removing similar image: images/Rumah adat gadang sumatera/d-353.png
# Removing similar image: images/Rumah adat gadang sumatera/d-32.png
# Removing similar image: images/Rumah adat gadang sumatera/y-12.png
# Removing similar image: images/Rumah adat gadang sumatera/d-374.png
# Removing similar image: images/Rumah adat gadang sumatera/d-297.png
# Removing similar image: images/Rumah adat gadang sumatera/y-39.png
# Removing similar image: images/Rumah adat gadang sumatera/g-599.png
# Removing similar image: images/Rumah adat gadang sumatera/d-381.png
# Removing similar image: images/Rumah adat gadang sumatera/g-7.png
# Removing similar image: images/Rumah adat gadang sumatera/d-377.png
# Removing similar image: images/Rumah adat gadang sumatera/g-656.png
# Removing similar image: images/Rumah adat gadang sumatera/d-92.png
# Removing similar image: images/Rumah adat gadang sumatera/d-66.png
# Removing similar image: images/Rumah adat gadang sumatera/g-450.png
# Removing similar image: images/Rumah adat gadang sumatera/d-178.png
# Removing similar image: images/Rumah adat gadang sumatera/d-316.png
# Removing similar image: images/Rumah adat gadang sumatera/d-122.png
# Removing similar image: images/Rumah adat gadang sumatera/d-42.png
# Removing similar image: images/Rumah adat gadang sumatera/d-225.png
# Removing similar image: images/Rumah adat gadang sumatera/d-226.png
# Removing similar image: images/Rumah adat gadang sumatera/d-33.png
# Removing similar image: images/Rumah adat gadang sumatera/d-254.png
# Removing similar image: images/Rumah adat gadang sumatera/g-325.png
# Removing similar image: images/Rumah adat gadang sumatera/d-292.png
# Removing similar image: images/Rumah adat gadang sumatera/d-142.png
# Removing similar image: images/Rumah adat gadang sumatera/d-11.png
# Removing similar image: images/Rumah adat gadang sumatera/d-193.png
# Removing similar image: images/Rumah adat gadang sumatera/d-248.png
# Removing similar image: images/Rumah adat gadang sumatera/d-31.png
# Removing similar image: images/Rumah adat gadang sumatera/d-153.png
# Removing similar image: images/Rumah adat gadang sumatera/d-135.png
# Removing similar image: images/Rumah adat gadang sumatera/d-348.png
# Removing similar image: images/Rumah adat gadang sumatera/g-100.png
# Removing similar image: images/Rumah adat gadang sumatera/d-278.png
# Removing similar image: images/Rumah adat gadang sumatera/d-77.png
# Removing similar image: images/Rumah adat gadang sumatera/d-443.png
# Removing similar image: images/Rumah adat gadang sumatera/d-87.png
# Removing similar image: images/Rumah adat gadang sumatera/y-1.png
# Removing similar image: images/Rumah adat gadang sumatera/d-475.png
# Removing similar image: images/Rumah adat gadang sumatera/d-45.png
# Removing similar image: images/Rumah adat gadang sumatera/d-62.png
# Removing similar image: images/Rumah adat gadang sumatera/g-238.png
# Removing similar image: images/Rumah adat gadang sumatera/g-625.png
# Removing similar image: images/Rumah adat gadang sumatera/d-192.png
# Removing similar image: images/Rumah adat gadang sumatera/g-613.png
# Removing similar image: images/Rumah adat gadang sumatera/g-609.png
# Removing similar image: images/Rumah adat gadang sumatera/d-93.png
# Removing similar image: images/Rumah adat gadang sumatera/d-116.png
# Removing similar image: images/Rumah adat gadang sumatera/d-25.png
# Removing similar image: images/Rumah adat gadang sumatera/d-403.png
# Removing similar image: images/Rumah adat gadang sumatera/d-18.png
# Removing similar image: images/Rumah adat gadang sumatera/d-107.png
# Removing similar image: images/Rumah adat gadang sumatera/d-90.png
# Removing similar image: images/Rumah adat gadang sumatera/d-63.png
# Removing similar image: images/Rumah adat gadang sumatera/d-156.png
# ----------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# Keyword: Rumah adat gadang
#
# Search engine: google
# URL: https://www.google.com/search?tbm=isch&q=Rumah%20adat%20gadang
# Number of images found: 823
#  11%|█         | 89/823 [00:02<00:18, 39.17it/s]
# Something went wrong while scraping the image at URL:
# https://encrypted-tbn2.gstatic.com/faviconV2?url=https://bisniswisata.co.id&client=VFE&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL&nfrp=2
#  14%|█▍        | 117/823 [00:02<00:14, 48.26it/s]
# Something went wrong while scraping the image at URL:
# https://encrypted-tbn2.gstatic.com/faviconV2?url=https://rudydewanto.com&client=VFE&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL&nfrp=2
#  20%|█▉        | 164/823 [00:03<00:11, 56.35it/s]
# Something went wrong while scraping the image at URL:
# https://encrypted-tbn2.gstatic.com/faviconV2?url=https://mondasiregar.com&client=VFE&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL&nfrp=2
#  26%|██▌       | 211/823 [00:04<00:13, 45.93it/s]
# Something went wrong while scraping the image at URL:
# https://encrypted-tbn2.gstatic.com/faviconV2?url=https://legitstage.com&client=VFE&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL&nfrp=2
#  29%|██▉       | 237/823 [00:05<00:15, 38.78it/s]
# Something went wrong while scraping the image at URL:
# https://encrypted-tbn2.gstatic.com/faviconV2?url=https://nabchelny.ru&client=VFE&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL&nfrp=2
#  32%|███▏      | 266/823 [00:06<00:20, 27.67it/s]
# Something went wrong while scraping the image at URL:
# https://encrypted-tbn2.gstatic.com/faviconV2?url=https://pesona.travel&client=VFE&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL&nfrp=2
#  38%|███▊      | 312/823 [00:07<00:13, 39.23it/s]
# Something went wrong while scraping the image at URL:
# https://encrypted-tbn2.gstatic.com/faviconV2?url=https://daftarkulinerindonesia.web.id&client=VFE&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL&nfrp=2
#  40%|████      | 333/823 [00:08<00:15, 31.62it/s]
# Something went wrong while scraping the image at URL:
# https://encrypted-tbn2.gstatic.com/faviconV2?url=https://dekadepos.com&client=VFE&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL&nfrp=2
#  44%|████▍     | 363/823 [00:09<00:11, 41.14it/s]
# Something went wrong while scraping the image at URL:
# https://encrypted-tbn2.gstatic.com/faviconV2?url=https://sumbarsatu.com&client=VFE&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL&nfrp=2
#  48%|████▊     | 397/823 [00:10<00:13, 30.47it/s]
# Something went wrong while scraping the image at URL:
# https://encrypted-tbn2.gstatic.com/faviconV2?url=https://souvenirplakat.com&client=VFE&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL&nfrp=2
#  62%|██████▏   | 514/823 [00:14<00:11, 26.19it/s]
# Something went wrong while scraping the image at URL:
# https://encrypted-tbn2.gstatic.com/faviconV2?url=https://argeo-demo.softmatics.com&client=VFE&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL&nfrp=2
#  63%|██████▎   | 517/823 [00:14<00:13, 23.15it/s]
# Something went wrong while scraping the image at URL:
# https://encrypted-tbn2.gstatic.com/faviconV2?url=https://gambarkeren.pro&client=VFE&size=16&type=FAVICON&fallback_opts=TYPE,SIZE,URL&nfrp=2
#  68%|██████▊   | 559/823 [00:14<00:03, 73.50it/s]
# Something went wrong while scraping the image at URL:
# https://fonts.gstatic.com/s/i/productlogos/lens_camera/v1/192px.svg
# 100%|██████████| 823/823 [00:18<00:00, 43.84it/s]
# Downloaded 810/823 images
#
# Search engine: bing
# URL: https://www.bing.com/images/search?q=Rumah%20adat%20gadang
# Number of images found: 131
# 100%|██████████| 131/131 [00:15<00:00,  8.32it/s]
# Downloaded 131/131 images
#
# Search engine: yahoo
# URL: https://images.search.yahoo.com/search/images?p=Rumah%20adat%20gadang
# Number of images found: 65
#   0%|          | 0/65 [00:00<?, ?it/s]
# Something went wrong while scraping the image at URL:
# https://s.yimg.com/fz/api/res/1.2/yZZanxayPzp_qswouslOqg--~C/YXBwaWQ9c3JjaGRkO2ZpPWZpbGw7aD05Njt3PTk2/https://tse4.mm.bing.net/th?q=Rumah+Adat+Indonesia
#   5%|▍         | 3/65 [00:00<00:07,  7.85it/s]
# Something went wrong while scraping the image at URL:
# https://s.yimg.com/fz/api/res/1.2/cEXeETcLx0eavbIYqoEFeA--~C/YXBwaWQ9c3JjaGRkO2ZpPWZpbGw7aD05Njt3PTk2/https://tse3.mm.bing.net/th?q=Menggambar+Rumah+Adat
# Something went wrong while scraping the image at URL:
# https://s.yimg.com/fz/api/res/1.2/YZ_SkjMi74Dt3FEt1Q08sQ--~C/YXBwaWQ9c3JjaGRkO2ZpPWZpbGw7aD05Njt3PTk2/https://tse3.mm.bing.net/th?q=Rumah+Joglo
#   9%|▉         | 6/65 [00:00<00:06,  9.30it/s]
# Something went wrong while scraping the image at URL:
# https://s.yimg.com/fz/api/res/1.2/FEVVFL4AcXH4tZlY_GatRA--~C/YXBwaWQ9c3JjaGRkO2ZpPWZpbGw7aD05Njt3PTk2/https://tse1.mm.bing.net/th?q=Rumah+Batak
# Something went wrong while scraping the image at URL:
# https://s.yimg.com/fz/api/res/1.2/XOpQx04O0F7ry8fDsS7uHQ--~C/YXBwaWQ9c3JjaGRkO2ZpPWZpbGw7aD05Njt3PTk2/https://tse2.mm.bing.net/th?q=Rumah+Adat+Sumbar
#  32%|███▏      | 21/65 [00:02<00:04, 10.08it/s]
# Something went wrong while scraping the image at URL:
# https://s.yimg.com/fz/api/res/1.2/oFHhxBRzNowVh91jb2SuGA--~C/YXBwaWQ9c3JjaGRkO2ZpPWZpbGw7aD05Njt3PTk2/https://tse2.mm.bing.net/th?q=Rumah+Bolon
#  43%|████▎     | 28/65 [00:02<00:03, 10.34it/s]
# Something went wrong while scraping the image at URL:
# https://s.yimg.com/fz/api/res/1.2/80bFzuy2SRBRL3ZDfzXvrQ--~C/YXBwaWQ9c3JjaGRkO2ZpPWZpbGw7aD05Njt3PTk2/https://tse3.mm.bing.net/th?q=Rumah+Adat+Di+Indonesia
#  46%|████▌     | 30/65 [00:03<00:03, 11.31it/s]
# Something went wrong while scraping the image at URL:
# https://s.yimg.com/fz/api/res/1.2/SnMB2nhL7m0j4cUlg8ldUg--~C/YXBwaWQ9c3JjaGRkO2ZpPWZpbGw7aD05Njt3PTk2/https://tse2.mm.bing.net/th?q=Foto+Rumah+Adat
#  52%|█████▏    | 34/65 [00:03<00:02, 10.77it/s]
# Something went wrong while scraping the image at URL:
# https://s.yimg.com/fz/api/res/1.2/UT.psiRYHR_N72f7ZkKung--~C/YXBwaWQ9c3JjaGRkO2ZpPWZpbGw7aD05Njt3PTk2/https://tse2.mm.bing.net/th?q=Rumah+Minangkabau
#  65%|██████▍   | 42/65 [00:04<00:02,  9.72it/s]
# Something went wrong while scraping the image at URL:
# https://s.yimg.com/fz/api/res/1.2/JU53enOmDRKhJBZxQ82nCA--~C/YXBwaWQ9c3JjaGRkO2ZpPWZpbGw7aD05Njt3PTk2/https://tse4.mm.bing.net/th?q=Rumah+Adat+Betawi
# Something went wrong while scraping the image at URL:
# https://s.yimg.com/fz/api/res/1.2/lEbT.SL0ksRYG2u_pJwm.w--~C/YXBwaWQ9c3JjaGRkO2ZpPWZpbGw7aD05Njt3PTk2/https://tse4.mm.bing.net/th?q=Rumah+Adat+Sumatera
#  74%|███████▍  | 48/65 [00:04<00:01, 12.99it/s]
# Something went wrong while scraping the image at URL:
# https://s.yimg.com/fz/api/res/1.2/g3mDQStBcRxHXlx_TS4Jkg--~C/YXBwaWQ9c3JjaGRkO2ZpPWZpbGw7aD05Njt3PTk2/https://tse3.mm.bing.net/th?q=Rumah+Padang
# Something went wrong while scraping the image at URL:
# https://s.yimg.com/fz/api/res/1.2/dFOHqlXM0wS4xvUJ6.eVDA--~C/YXBwaWQ9c3JjaGRkO2ZpPWZpbGw7aD05Njt3PTk2/https://tse4.mm.bing.net/th?q=Rumah+Minang
#  86%|████████▌ | 56/65 [00:05<00:00, 11.97it/s]
# Something went wrong while scraping the image at URL:
# https://s.yimg.com/fz/api/res/1.2/SxYp42Fk5iRjRhRQPTdMOg--~C/YXBwaWQ9c3JjaGRkO2ZpPWZpbGw7aD05Njt3PTk2/https://tse2.mm.bing.net/th?q=Gambar+Rumah+Gadang
# Something went wrong while scraping the image at URL:
# https://s.yimg.com/fz/api/res/1.2/_FMDhtd.ztnyTpzIhT4rig--~C/YXBwaWQ9c3JjaGRkO2ZpPWZpbGw7aD05Njt3PTk2/https://tse2.mm.bing.net/th?q=Rumah+Adat+Yogyakarta
# 100%|██████████| 65/65 [00:06<00:00,  9.83it/s]
# Downloaded 50/65 images
#
# Search engine: duckduckgo
# URL: https://duckduckgo.com/?q=Rumah%20adat%20gadang&iax=images&ia=images
# Number of images found: 460
# 100%|██████████| 460/460 [00:49<00:00,  9.33it/s]
# Downloaded 460/460 images
#
# Checking for duplicate images by comparing SHA-256 hash
# Removing duplicate image: images/Rumah adat gadang/g-410.png
# Removing duplicate image: images/Rumah adat gadang/g-464.png
# Removing duplicate image: images/Rumah adat gadang/g-73.png
# Removing duplicate image: images/Rumah adat gadang/g-573.png
# Removing duplicate image: images/Rumah adat gadang/g-624.png
# Removing duplicate image: images/Rumah adat gadang/g-785.png
# Removing duplicate image: images/Rumah adat gadang/g-379.png
# Removing duplicate image: images/Rumah adat gadang/g-416.png
# Removing duplicate image: images/Rumah adat gadang/d-39.png
# Removing duplicate image: images/Rumah adat gadang/g-752.png
# Removing duplicate image: images/Rumah adat gadang/y-46.png
# Removing duplicate image: images/Rumah adat gadang/y-31.png
# Removing duplicate image: images/Rumah adat gadang/d-127.png
# Removing duplicate image: images/Rumah adat gadang/g-440.png
# Removing duplicate image: images/Rumah adat gadang/b-24.png
# Removing duplicate image: images/Rumah adat gadang/b-63.png
# Removing duplicate image: images/Rumah adat gadang/g-434.png
# Removing duplicate image: images/Rumah adat gadang/g-583.png
# Removing duplicate image: images/Rumah adat gadang/y-17.png
# Removing duplicate image: images/Rumah adat gadang/d-68.png
# Removing duplicate image: images/Rumah adat gadang/d-105.png
# Removing duplicate image: images/Rumah adat gadang/g-482.png
# Removing duplicate image: images/Rumah adat gadang/y-41.png
# Removing duplicate image: images/Rumah adat gadang/b-56.png
# Removing duplicate image: images/Rumah adat gadang/d-96.png
# Removing duplicate image: images/Rumah adat gadang/g-740.png
# Removing duplicate image: images/Rumah adat gadang/b-75.png
# Removing duplicate image: images/Rumah adat gadang/g-317.png
# Removing duplicate image: images/Rumah adat gadang/d-19.png
# Removing duplicate image: images/Rumah adat gadang/g-390.png
# Removing duplicate image: images/Rumah adat gadang/g-353.png
# Removing duplicate image: images/Rumah adat gadang/d-80.png
# Removing duplicate image: images/Rumah adat gadang/g-424.png
# Removing duplicate image: images/Rumah adat gadang/g-187.png
# Removing duplicate image: images/Rumah adat gadang/g-422.png
# Removing duplicate image: images/Rumah adat gadang/d-37.png
# Removing duplicate image: images/Rumah adat gadang/g-639.png
# Removing duplicate image: images/Rumah adat gadang/g-760.png
# Removing duplicate image: images/Rumah adat gadang/g-229.png
# Removing duplicate image: images/Rumah adat gadang/g-493.png
# Removing duplicate image: images/Rumah adat gadang/b-51.png
# Removing duplicate image: images/Rumah adat gadang/d-17.png
# Removing duplicate image: images/Rumah adat gadang/y-50.png
# Removing duplicate image: images/Rumah adat gadang/g-283.png
# Removing duplicate image: images/Rumah adat gadang/y-35.png
# Removing duplicate image: images/Rumah adat gadang/g-36.png
# Removing duplicate image: images/Rumah adat gadang/y-23.png
# Removing duplicate image: images/Rumah adat gadang/g-690.png
# Removing duplicate image: images/Rumah adat gadang/g-446.png
# Removing duplicate image: images/Rumah adat gadang/g-311.png
# Removing duplicate image: images/Rumah adat gadang/g-208.png
# Removing duplicate image: images/Rumah adat gadang/g-28.png
# Removing duplicate image: images/Rumah adat gadang/g-472.png
# Removing duplicate image: images/Rumah adat gadang/d-29.png
# Removing duplicate image: images/Rumah adat gadang/b-85.png
# Removing duplicate image: images/Rumah adat gadang/d-58.png
# Removing duplicate image: images/Rumah adat gadang/g-118.png
# Removing duplicate image: images/Rumah adat gadang/g-408.png
# Removing duplicate image: images/Rumah adat gadang/y-3.png
# Removing duplicate image: images/Rumah adat gadang/b-117.png
# Removing duplicate image: images/Rumah adat gadang/g-593.png
# Removing duplicate image: images/Rumah adat gadang/d-64.png
# Removing duplicate image: images/Rumah adat gadang/g-8.png
# Removing duplicate image: images/Rumah adat gadang/b-52.png
# Removing duplicate image: images/Rumah adat gadang/g-647.png
# Removing duplicate image: images/Rumah adat gadang/g-718.png
# Removing duplicate image: images/Rumah adat gadang/g-436.png
# Removing duplicate image: images/Rumah adat gadang/d-52.png
# Removing duplicate image: images/Rumah adat gadang/g-102.png
# Removing duplicate image: images/Rumah adat gadang/g-438.png
# Removing duplicate image: images/Rumah adat gadang/g-6.png
# Removing duplicate image: images/Rumah adat gadang/g-308.png
# Removing duplicate image: images/Rumah adat gadang/b-94.png
# Removing duplicate image: images/Rumah adat gadang/y-25.png
# Removing duplicate image: images/Rumah adat gadang/b-74.png
# Removing duplicate image: images/Rumah adat gadang/d-144.png
# Removing duplicate image: images/Rumah adat gadang/g-474.png
# Removing duplicate image: images/Rumah adat gadang/b-115.png
# Removing duplicate image: images/Rumah adat gadang/g-254.png
# Removing duplicate image: images/Rumah adat gadang/g-344.png
# Removing duplicate image: images/Rumah adat gadang/g-287.png
# Removing duplicate image: images/Rumah adat gadang/g-168.png
# Removing duplicate image: images/Rumah adat gadang/g-244.png
# Removing duplicate image: images/Rumah adat gadang/d-16.png
# Removing duplicate image: images/Rumah adat gadang/g-775.png
# Removing duplicate image: images/Rumah adat gadang/d-119.png
# Removing duplicate image: images/Rumah adat gadang/b-54.png
# Removing duplicate image: images/Rumah adat gadang/b-40.png
# Removing duplicate image: images/Rumah adat gadang/g-476.png
# Removing duplicate image: images/Rumah adat gadang/y-26.png
# Removing duplicate image: images/Rumah adat gadang/g-300.png
# Removing duplicate image: images/Rumah adat gadang/y-13.png
# Removing duplicate image: images/Rumah adat gadang/g-799.png
# Removing duplicate image: images/Rumah adat gadang/g-581.png
# Removing duplicate image: images/Rumah adat gadang/b-7.png
# Removing duplicate image: images/Rumah adat gadang/d-148.png
# Removing duplicate image: images/Rumah adat gadang/d-20.png
# Removing duplicate image: images/Rumah adat gadang/b-47.png
# Removing duplicate image: images/Rumah adat gadang/d-46.png
# Removing duplicate image: images/Rumah adat gadang/b-19.png
# Removing duplicate image: images/Rumah adat gadang/g-610.png
# Removing duplicate image: images/Rumah adat gadang/d-132.png
# Removing duplicate image: images/Rumah adat gadang/y-45.png
# Removing duplicate image: images/Rumah adat gadang/g-222.png
# Removing duplicate image: images/Rumah adat gadang/g-248.png
# Removing duplicate image: images/Rumah adat gadang/g-189.png
# Removing duplicate image: images/Rumah adat gadang/b-70.png
# Removing duplicate image: images/Rumah adat gadang/b-28.png
# Removing duplicate image: images/Rumah adat gadang/g-456.png
# Removing duplicate image: images/Rumah adat gadang/g-720.png
# Removing duplicate image: images/Rumah adat gadang/b-25.png
# Removing duplicate image: images/Rumah adat gadang/y-36.png
# Removing duplicate image: images/Rumah adat gadang/b-83.png
# ...
# Removing duplicate image: images/gadang sumatera/g-316.png
# Removing duplicate image: images/gadang sumatera/g-531.png
# Removing duplicate image: images/gadang sumatera/g-209.png
# Removing duplicate image: images/gadang sumatera/b-110.png
# Removing duplicate image: images/gadang sumatera/g-656.png
# Removing duplicate image: images/gadang sumatera/b-111.png
# Removing duplicate image: images/gadang sumatera/b-48.png
# Removing duplicate image: images/gadang sumatera/d-92.png
# Removing duplicate image: images/gadang sumatera/d-66.png
# Removing duplicate image: images/gadang sumatera/b-104.png
# Removing duplicate image: images/gadang sumatera/d-122.png
# Removing duplicate image: images/gadang sumatera/d-42.png
# Removing duplicate image: images/gadang sumatera/g-529.png
# Removing duplicate image: images/gadang sumatera/b-13.png
# Removing duplicate image: images/gadang sumatera/y-61.png
# Removing duplicate image: images/gadang sumatera/y-22.png
# Removing duplicate image: images/gadang sumatera/y-57.png
# Removing duplicate image: images/gadang sumatera/b-120.png
# Removing duplicate image: images/gadang sumatera/g-232.png
# Removing duplicate image: images/gadang sumatera/g-296.png
# Removing duplicate image: images/gadang sumatera/g-470.png
# Removing duplicate image: images/gadang sumatera/d-33.png
# Removing duplicate image: images/gadang sumatera/b-95.png
# Removing duplicate image: images/gadang sumatera/g-69.png
# Removing duplicate image: images/gadang sumatera/g-320.png
# Removing duplicate image: images/gadang sumatera/g-675.png
# Removing duplicate image: images/gadang sumatera/g-19.png
# Removing duplicate image: images/gadang sumatera/g-528.png
# Removing duplicate image: images/gadang sumatera/g-741.png
# Removing duplicate image: images/gadang sumatera/y-10.png
# Removing duplicate image: images/gadang sumatera/g-673.png
# Removing duplicate image: images/gadang sumatera/b-60.png
# Removing duplicate image: images/gadang sumatera/d-70.png
# Removing duplicate image: images/gadang sumatera/b-21.png
# Removing duplicate image: images/gadang sumatera/g-461.png
# Removing duplicate image: images/gadang sumatera/g-149.png
# Removing duplicate image: images/gadang sumatera/g-559.png
# Removing duplicate image: images/gadang sumatera/g-141.png
# Removing duplicate image: images/gadang sumatera/g-211.png
# Removing duplicate image: images/gadang sumatera/d-149.png
# Removing duplicate image: images/gadang sumatera/b-93.png
# Removing duplicate image: images/gadang sumatera/y-80.png
# Removing duplicate image: images/gadang sumatera/d-142.png
# Removing duplicate image: images/gadang sumatera/g-262.png
# Removing duplicate image: images/gadang sumatera/y-65.png
# Removing duplicate image: images/gadang sumatera/d-89.png
# Removing duplicate image: images/gadang sumatera/g-157.png
# Removing duplicate image: images/gadang sumatera/y-21.png
# Removing duplicate image: images/gadang sumatera/d-31.png
# Removing duplicate image: images/gadang sumatera/g-370.png
# Removing duplicate image: images/gadang sumatera/g-170.png
# Removing duplicate image: images/gadang sumatera/g-519.png
# Removing duplicate image: images/gadang sumatera/d-153.png
# Removing duplicate image: images/gadang sumatera/g-730.png
# Removing duplicate image: images/gadang sumatera/b-62.png
# Removing duplicate image: images/gadang sumatera/y-86.png
# Removing duplicate image: images/gadang sumatera/g-54.png
# Removing duplicate image: images/gadang sumatera/g-454.png
# Removing duplicate image: images/gadang sumatera/y-85.png
# Removing duplicate image: images/gadang sumatera/g-333.png
# Removing duplicate image: images/gadang sumatera/b-22.png
# Removing duplicate image: images/gadang sumatera/b-130.png
# Removing duplicate image: images/gadang sumatera/b-33.png
# Removing duplicate image: images/gadang sumatera/g-606.png
# Removing duplicate image: images/gadang sumatera/y-11.png
# Removing duplicate image: images/gadang sumatera/y-90.png
# Removing duplicate image: images/gadang sumatera/g-100.png
# Removing duplicate image: images/gadang sumatera/b-67.png
# Removing duplicate image: images/gadang sumatera/d-40.png
# Removing duplicate image: images/gadang sumatera/y-28.png
# Removing duplicate image: images/gadang sumatera/g-314.png
# Removing duplicate image: images/gadang sumatera/d-77.png
# Removing duplicate image: images/gadang sumatera/d-121.png
# Removing duplicate image: images/gadang sumatera/b-12.png
# Removing duplicate image: images/gadang sumatera/y-70.png
# Removing duplicate image: images/gadang sumatera/g-612.png
# Removing duplicate image: images/gadang sumatera/d-87.png
# Removing duplicate image: images/gadang sumatera/g-83.png
# Removing duplicate image: images/gadang sumatera/g-761.png
# Removing duplicate image: images/gadang sumatera/b-36.png
# Removing duplicate image: images/gadang sumatera/y-1.png
# Removing duplicate image: images/gadang sumatera/y-42.png
# Removing duplicate image: images/gadang sumatera/g-548.png
# Removing duplicate image: images/gadang sumatera/d-45.png
# Removing duplicate image: images/gadang sumatera/b-97.png
# Removing duplicate image: images/gadang sumatera/g-442.png
# Removing duplicate image: images/gadang sumatera/d-62.png
# Removing duplicate image: images/gadang sumatera/b-122.png
# Removing duplicate image: images/gadang sumatera/g-818.png
# Removing duplicate image: images/gadang sumatera/b-80.png
# Removing duplicate image: images/gadang sumatera/y-6.png
# Removing duplicate image: images/gadang sumatera/g-238.png
# Removing duplicate image: images/gadang sumatera/b-101.png
# Removing duplicate image: images/gadang sumatera/g-713.png
# Removing duplicate image: images/gadang sumatera/g-625.png
# Removing duplicate image: images/gadang sumatera/d-81.png
# Removing duplicate image: images/gadang sumatera/g-413.png
# Removing duplicate image: images/gadang sumatera/g-270.png
# Removing duplicate image: images/gadang sumatera/g-75.png
# Removing duplicate image: images/gadang sumatera/y-15.png
# Removing duplicate image: images/gadang sumatera/b-76.png
# Removing duplicate image: images/gadang sumatera/d-93.png
# Removing duplicate image: images/gadang sumatera/g-391.png
# Removing duplicate image: images/gadang sumatera/g-497.png
# Removing duplicate image: images/gadang sumatera/b-66.png
# Removing duplicate image: images/gadang sumatera/d-25.png
# Removing duplicate image: images/gadang sumatera/d-57.png
# Removing duplicate image: images/gadang sumatera/b-128.png
# Removing duplicate image: images/gadang sumatera/d-18.png
# Removing duplicate image: images/gadang sumatera/g-21.png
# Removing duplicate image: images/gadang sumatera/g-747.png
# Removing duplicate image: images/gadang sumatera/d-107.png
# Removing duplicate image: images/gadang sumatera/d-90.png
# Removing duplicate image: images/gadang sumatera/g-691.png
# Removing duplicate image: images/gadang sumatera/y-9.png
# Removing duplicate image: images/gadang sumatera/g-166.png
# Removing duplicate image: images/gadang sumatera/y-67.png
# Removing duplicate image: images/gadang sumatera/y-51.png
# Removing duplicate image: images/gadang sumatera/d-27.png
# Removing duplicate image: images/gadang sumatera/g-291.png
# Removing duplicate image: images/gadang sumatera/d-30.png
# Removing duplicate image: images/gadang sumatera/d-63.png
#
# Checking for similar images
# Removing similar image: images/gadang sumatera/b-58.png
# Removing similar image: images/gadang sumatera/d-133.png
# Removing similar image: images/gadang sumatera/g-733.png
# Removing similar image: images/gadang sumatera/d-182.png
# Removing similar image: images/gadang sumatera/d-246.png
# Removing similar image: images/gadang sumatera/d-65.png
# Removing similar image: images/gadang sumatera/d-47.png
# Removing similar image: images/gadang sumatera/b-89.png
# Removing similar image: images/gadang sumatera/b-81.png
# Removing similar image: images/gadang sumatera/d-111.png
# Removing similar image: images/gadang sumatera/g-31.png
# Removing similar image: images/gadang sumatera/b-109.png
# Removing similar image: images/gadang sumatera/g-282.png
# Removing similar image: images/gadang sumatera/d-72.png
# Removing similar image: images/gadang sumatera/d-407.png
# Removing similar image: images/gadang sumatera/b-59.png
# Removing similar image: images/gadang sumatera/b-114.png
# Removing similar image: images/gadang sumatera/d-161.png
# Removing similar image: images/gadang sumatera/b-118.png
# Removing similar image: images/gadang sumatera/d-396.png
# Removing similar image: images/gadang sumatera/d-342.png
# Removing similar image: images/gadang sumatera/d-82.png
# Removing similar image: images/gadang sumatera/g-595.png
# Removing similar image: images/gadang sumatera/g-690.png
# Removing similar image: images/gadang sumatera/d-325.png
# Removing similar image: images/gadang sumatera/d-318.png
# Removing similar image: images/gadang sumatera/g-666.png
# Removing similar image: images/gadang sumatera/g-725.png
# Removing similar image: images/gadang sumatera/g-593.png
# Removing similar image: images/gadang sumatera/g-718.png
# Removing similar image: images/gadang sumatera/g-702.png
# Removing similar image: images/gadang sumatera/d-335.png
# Removing similar image: images/gadang sumatera/d-222.png
# Removing similar image: images/gadang sumatera/d-117.png
# Removing similar image: images/gadang sumatera/d-16.png
# Removing similar image: images/gadang sumatera/d-389.png
# Removing similar image: images/gadang sumatera/g-43.png
# Removing similar image: images/gadang sumatera/b-106.png
# Removing similar image: images/gadang sumatera/g-72.png
# Removing similar image: images/gadang sumatera/d-48.png
# Removing similar image: images/gadang sumatera/d-101.png
# Removing similar image: images/gadang sumatera/d-339.png
# Removing similar image: images/gadang sumatera/b-6.png
# Removing similar image: images/gadang sumatera/y-48.png
# Removing similar image: images/gadang sumatera/g-169.png
# Removing similar image: images/gadang sumatera/d-132.png
# Removing similar image: images/gadang sumatera/b-70.png
# Removing similar image: images/gadang sumatera/d-366.png
# Removing similar image: images/gadang sumatera/g-664.png
# Removing similar image: images/gadang sumatera/d-476.png
# Removing similar image: images/gadang sumatera/g-720.png
# Removing similar image: images/gadang sumatera/g-60.png
# Removing similar image: images/gadang sumatera/d-310.png
# Removing similar image: images/gadang sumatera/g-249.png
# Removing similar image: images/gadang sumatera/b-30.png
# Removing similar image: images/gadang sumatera/g-88.png
# Removing similar image: images/gadang sumatera/g-565.png
# Removing similar image: images/gadang sumatera/d-12.png
# Removing similar image: images/gadang sumatera/b-113.png
# Removing similar image: images/gadang sumatera/b-37.png
# Removing similar image: images/gadang sumatera/g-698.png
# Removing similar image: images/gadang sumatera/y-72.png
# Removing similar image: images/gadang sumatera/g-579.png
# Removing similar image: images/gadang sumatera/b-96.png
# Removing similar image: images/gadang sumatera/g-484.png
# Removing similar image: images/gadang sumatera/d-83.png
# Removing similar image: images/gadang sumatera/g-615.png
# Removing similar image: images/gadang sumatera/d-375.png
# Removing similar image: images/gadang sumatera/d-224.png
# Removing similar image: images/gadang sumatera/g-510.png
# Removing similar image: images/gadang sumatera/g-134.png
# Removing similar image: images/gadang sumatera/d-5.png
# Removing similar image: images/gadang sumatera/b-2.png
# Removing similar image: images/gadang sumatera/d-359.png
# Removing similar image: images/gadang sumatera/d-6.png
# Removing similar image: images/gadang sumatera/d-291.png
# Removing similar image: images/gadang sumatera/g-727.png
# Removing similar image: images/gadang sumatera/d-14.png
# Removing similar image: images/gadang sumatera/d-125.png
# Removing similar image: images/gadang sumatera/g-163.png
# Removing similar image: images/gadang sumatera/g-630.png
# Removing similar image: images/gadang sumatera/g-243.png
# Removing similar image: images/gadang sumatera/g-721.png
# Removing similar image: images/gadang sumatera/d-388.png
# Removing similar image: images/gadang sumatera/b-16.png
# Removing similar image: images/gadang sumatera/d-124.png
# Removing similar image: images/gadang sumatera/g-396.png
# Removing similar image: images/gadang sumatera/y-77.png
# Removing similar image: images/gadang sumatera/d-266.png
# Removing similar image: images/gadang sumatera/d-171.png
# Removing similar image: images/gadang sumatera/b-127.png
# Removing similar image: images/gadang sumatera/d-333.png
# Removing similar image: images/gadang sumatera/g-462.png
# Removing similar image: images/gadang sumatera/g-628.png
# Removing similar image: images/gadang sumatera/g-553.png
# Removing similar image: images/gadang sumatera/d-49.png
# Removing similar image: images/gadang sumatera/g-601.png
# Removing similar image: images/gadang sumatera/g-259.png
# Removing similar image: images/gadang sumatera/d-251.png
# Removing similar image: images/gadang sumatera/d-104.png
# Removing similar image: images/gadang sumatera/d-491.png
# Removing similar image: images/gadang sumatera/d-313.png
# Removing similar image: images/gadang sumatera/d-118.png
# Removing similar image: images/gadang sumatera/g-547.png
# Removing similar image: images/gadang sumatera/g-591.png
# Removing similar image: images/gadang sumatera/y-18.png
# Removing similar image: images/gadang sumatera/g-689.png
# Removing similar image: images/gadang sumatera/b-91.png
# Removing similar image: images/gadang sumatera/d-379.png
# Removing similar image: images/gadang sumatera/y-71.png
# Removing similar image: images/gadang sumatera/g-7.png
# Removing similar image: images/gadang sumatera/g-200.png
# Removing similar image: images/gadang sumatera/d-377.png
# Removing similar image: images/gadang sumatera/d-286.png
# Removing similar image: images/gadang sumatera/g-492.png
# Removing similar image: images/gadang sumatera/g-676.png
# Removing similar image: images/gadang sumatera/d-316.png
# Removing similar image: images/gadang sumatera/y-78.png
# Removing similar image: images/gadang sumatera/d-334.png
# Removing similar image: images/gadang sumatera/g-206.png
# Removing similar image: images/gadang sumatera/g-418.png
# Removing similar image: images/gadang sumatera/y-34.png
# Removing similar image: images/gadang sumatera/g-1.png
# Removing similar image: images/gadang sumatera/d-102.png
# Removing similar image: images/gadang sumatera/g-736.png
# Removing similar image: images/gadang sumatera/d-11.png
# Removing similar image: images/gadang sumatera/g-439.png
# Removing similar image: images/gadang sumatera/d-193.png
# Removing similar image: images/gadang sumatera/b-64.png
# Removing similar image: images/gadang sumatera/d-255.png
# Removing similar image: images/gadang sumatera/d-135.png
# Removing similar image: images/gadang sumatera/d-158.png
# Removing similar image: images/gadang sumatera/g-577.png
# Removing similar image: images/gadang sumatera/d-322.png
# Removing similar image: images/gadang sumatera/d-295.png
# Removing similar image: images/gadang sumatera/d-285.png
# Removing similar image: images/gadang sumatera/d-259.png
# Removing similar image: images/gadang sumatera/d-114.png
# Removing similar image: images/gadang sumatera/d-95.png
# Removing similar image: images/gadang sumatera/g-226.png
# Removing similar image: images/gadang sumatera/g-130.png
# Removing similar image: images/gadang sumatera/d-192.png
# Removing similar image: images/gadang sumatera/d-185.png
# Removing similar image: images/gadang sumatera/g-22.png
# Removing similar image: images/gadang sumatera/d-239.png
# Removing similar image: images/gadang sumatera/d-247.png
# Removing similar image: images/gadang sumatera/d-116.png
# Removing similar image: images/gadang sumatera/d-190.png
# Removing similar image: images/gadang sumatera/g-122.png
# Removing similar image: images/gadang sumatera/g-587.png
# Removing similar image: images/gadang sumatera/d-61.png
# Removing similar image: images/gadang sumatera/d-301.png
# Removing similar image: images/gadang sumatera/d-270.png
# Removing similar image: images/gadang sumatera/d-156.png
# ----------------------------------------------------------------------------------------------------

# %%
# !zip images.zip images/*/*
# !rm -rf images
# Out:
#   adding: images/gadang sumatera/b-100.png (deflated 0%)
#   adding: images/gadang sumatera/b-112.png (deflated 0%)
#   adding: images/gadang sumatera/b-117.png (deflated 0%)
#   adding: images/gadang sumatera/b-121.png (deflated 0%)
#   adding: images/gadang sumatera/b-123.png (deflated 0%)
#   adding: images/gadang sumatera/b-125.png (deflated 0%)
#   adding: images/gadang sumatera/b-126.png (deflated 0%)
#   adding: images/gadang sumatera/b-14.png (deflated 0%)
#   adding: images/gadang sumatera/b-15.png (deflated 0%)
#   adding: images/gadang sumatera/b-17.png (deflated 0%)
#   adding: images/gadang sumatera/b-19.png (deflated 1%)
#   adding: images/gadang sumatera/b-1.png (deflated 0%)
#   adding: images/gadang sumatera/b-24.png (deflated 0%)
#   adding: images/gadang sumatera/b-26.png (deflated 0%)
#   adding: images/gadang sumatera/b-27.png (deflated 0%)
#   adding: images/gadang sumatera/b-29.png (deflated 0%)
#   adding: images/gadang sumatera/b-34.png (deflated 0%)
#   adding: images/gadang sumatera/b-35.png (deflated 0%)
#   adding: images/gadang sumatera/b-38.png (deflated 0%)
#   adding: images/gadang sumatera/b-3.png (deflated 0%)
#   adding: images/gadang sumatera/b-40.png (deflated 0%)
#   adding: images/gadang sumatera/b-41.png (deflated 0%)
#   adding: images/gadang sumatera/b-42.png (deflated 0%)
#   adding: images/gadang sumatera/b-47.png (deflated 0%)
#   adding: images/gadang sumatera/b-49.png (deflated 0%)
#   adding: images/gadang sumatera/b-4.png (deflated 0%)
#   adding: images/gadang sumatera/b-53.png (deflated 0%)
#   adding: images/gadang sumatera/b-54.png (deflated 2%)
#   adding: images/gadang sumatera/b-57.png (deflated 0%)
#   adding: images/gadang sumatera/b-5.png (deflated 0%)
#   adding: images/gadang sumatera/b-72.png (deflated 1%)
#   adding: images/gadang sumatera/b-73.png (deflated 0%)
#   adding: images/gadang sumatera/b-75.png (deflated 0%)
#   adding: images/gadang sumatera/b-7.png (deflated 0%)
#   adding: images/gadang sumatera/b-82.png (deflated 0%)
#   adding: images/gadang sumatera/b-86.png (deflated 0%)
#   adding: images/gadang sumatera/b-8.png (deflated 0%)
#   adding: images/gadang sumatera/b-90.png (deflated 0%)
#   adding: images/gadang sumatera/b-92.png (deflated 0%)
#   adding: images/gadang sumatera/b-98.png (deflated 0%)
#   adding: images/gadang sumatera/d-100.png (deflated 0%)
#   adding: images/gadang sumatera/d-105.png (deflated 0%)
#   adding: images/gadang sumatera/d-106.png (deflated 0%)
#   adding: images/gadang sumatera/d-108.png (deflated 0%)
#   adding: images/gadang sumatera/d-109.png (deflated 0%)
#   adding: images/gadang sumatera/d-10.png (deflated 0%)
#   adding: images/gadang sumatera/d-110.png (deflated 0%)
#   adding: images/gadang sumatera/d-119.png (deflated 0%)
#   adding: images/gadang sumatera/d-120.png (deflated 0%)
#   adding: images/gadang sumatera/d-127.png (deflated 0%)
#   adding: images/gadang sumatera/d-128.png (deflated 0%)
#   adding: images/gadang sumatera/d-130.png (deflated 0%)
#   adding: images/gadang sumatera/d-131.png (deflated 0%)
#   adding: images/gadang sumatera/d-136.png (deflated 0%)
#   adding: images/gadang sumatera/d-139.png (deflated 0%)
#   adding: images/gadang sumatera/d-141.png (deflated 0%)
#   adding: images/gadang sumatera/d-143.png (deflated 0%)
#   adding: images/gadang sumatera/d-145.png (deflated 1%)
#   adding: images/gadang sumatera/d-146.png (deflated 0%)
#   adding: images/gadang sumatera/d-147.png (deflated 0%)
#   adding: images/gadang sumatera/d-150.png (deflated 0%)
#   adding: images/gadang sumatera/d-152.png (deflated 0%)
#   adding: images/gadang sumatera/d-154.png (deflated 0%)
#   adding: images/gadang sumatera/d-155.png (deflated 0%)
#   adding: images/gadang sumatera/d-157.png (deflated 0%)
#   adding: images/gadang sumatera/d-159.png (deflated 0%)
#   adding: images/gadang sumatera/d-15.png (deflated 0%)
#   adding: images/gadang sumatera/d-160.png (deflated 1%)
#   adding: images/gadang sumatera/d-162.png (deflated 0%)
#   adding: images/gadang sumatera/d-163.png (deflated 0%)
#   adding: images/gadang sumatera/d-164.png (deflated 1%)
#   adding: images/gadang sumatera/d-165.png (deflated 0%)
#   adding: images/gadang sumatera/d-166.png (deflated 0%)
#   adding: images/gadang sumatera/d-167.png (deflated 0%)
#   adding: images/gadang sumatera/d-168.png (deflated 0%)
#   adding: images/gadang sumatera/d-169.png (deflated 0%)
#   adding: images/gadang sumatera/d-170.png (deflated 0%)
#   adding: images/gadang sumatera/d-172.png (deflated 0%)
#   adding: images/gadang sumatera/d-173.png (deflated 0%)
#   adding: images/gadang sumatera/d-174.png (deflated 0%)
#   adding: images/gadang sumatera/d-175.png (deflated 0%)
#   adding: images/gadang sumatera/d-176.png (deflated 0%)
#   adding: images/gadang sumatera/d-177.png (deflated 0%)
#   adding: images/gadang sumatera/d-178.png (deflated 0%)
#   adding: images/gadang sumatera/d-179.png (deflated 0%)
#   adding: images/gadang sumatera/d-17.png (deflated 0%)
#   adding: images/gadang sumatera/d-180.png (deflated 0%)
#   adding: images/gadang sumatera/d-181.png (deflated 0%)
#   adding: images/gadang sumatera/d-183.png (deflated 0%)
#   adding: images/gadang sumatera/d-184.png (deflated 0%)
#   adding: images/gadang sumatera/d-186.png (deflated 0%)
#   adding: images/gadang sumatera/d-187.png (deflated 0%)
#   adding: images/gadang sumatera/d-188.png (deflated 1%)
#   adding: images/gadang sumatera/d-189.png (deflated 1%)
#   adding: images/gadang sumatera/d-191.png (deflated 1%)
#   adding: images/gadang sumatera/d-194.png (deflated 0%)
#   adding: images/gadang sumatera/d-195.png (deflated 0%)
#   adding: images/gadang sumatera/d-196.png (deflated 0%)
#   adding: images/gadang sumatera/d-197.png (deflated 0%)
#   adding: images/gadang sumatera/d-198.png (deflated 1%)
#   adding: images/gadang sumatera/d-199.png (deflated 0%)
#   adding: images/gadang sumatera/d-19.png (deflated 0%)
#   adding: images/gadang sumatera/d-1.png (deflated 0%)
#   adding: images/gadang sumatera/d-200.png (deflated 0%)
#   adding: images/gadang sumatera/d-201.png (deflated 0%)
#   adding: images/gadang sumatera/d-202.png (deflated 1%)
#   adding: images/gadang sumatera/d-203.png (deflated 0%)
#   adding: images/gadang sumatera/d-204.png (deflated 0%)
#   adding: images/gadang sumatera/d-205.png (deflated 0%)
#   adding: images/gadang sumatera/d-206.png (deflated 0%)
#   adding: images/gadang sumatera/d-207.png (deflated 0%)
#   adding: images/gadang sumatera/d-208.png (deflated 0%)
#   adding: images/gadang sumatera/d-209.png (deflated 0%)
#   adding: images/gadang sumatera/d-210.png (deflated 0%)
#   adding: images/gadang sumatera/d-211.png (deflated 0%)
#   adding: images/gadang sumatera/d-212.png (deflated 0%)
#   adding: images/gadang sumatera/d-213.png (deflated 0%)
#   adding: images/gadang sumatera/d-214.png (deflated 0%)
#   adding: images/gadang sumatera/d-215.png (deflated 0%)
#   adding: images/gadang sumatera/d-216.png (deflated 0%)
#   adding: images/gadang sumatera/d-217.png (deflated 0%)
#   adding: images/gadang sumatera/d-218.png (deflated 0%)
#   adding: images/gadang sumatera/d-219.png (deflated 0%)
#   adding: images/gadang sumatera/d-21.png (deflated 0%)
#   adding: images/gadang sumatera/d-220.png (deflated 0%)
#   adding: images/gadang sumatera/d-221.png (deflated 0%)
#   adding: images/gadang sumatera/d-223.png (deflated 0%)
#   adding: images/gadang sumatera/d-225.png (deflated 0%)
#   adding: images/gadang sumatera/d-226.png (deflated 0%)
#   adding: images/gadang sumatera/d-227.png (deflated 1%)
#   adding: images/gadang sumatera/d-228.png (deflated 0%)
#   adding: images/gadang sumatera/d-229.png (deflated 0%)
#   adding: images/gadang sumatera/d-230.png (deflated 1%)
#   adding: images/gadang sumatera/d-231.png (deflated 2%)
#   adding: images/gadang sumatera/d-232.png (deflated 0%)
#   adding: images/gadang sumatera/d-233.png (deflated 0%)
#   adding: images/gadang sumatera/d-234.png (deflated 0%)
#   adding: images/gadang sumatera/d-235.png (deflated 0%)
#   adding: images/gadang sumatera/d-236.png (deflated 1%)
#   adding: images/gadang sumatera/d-237.png (deflated 0%)
#   adding: images/gadang sumatera/d-238.png (deflated 1%)
#   adding: images/gadang sumatera/d-240.png (deflated 0%)
#   adding: images/gadang sumatera/d-241.png (deflated 0%)
#   adding: images/gadang sumatera/d-242.png (deflated 0%)
#   adding: images/gadang sumatera/d-243.png (deflated 0%)
#   adding: images/gadang sumatera/d-244.png (deflated 0%)
#   adding: images/gadang sumatera/d-245.png (deflated 0%)
#   adding: images/gadang sumatera/d-248.png (deflated 0%)
#   adding: images/gadang sumatera/d-249.png (deflated 0%)
#   adding: images/gadang sumatera/d-250.png (deflated 0%)
#   adding: images/gadang sumatera/d-253.png (deflated 0%)
#   adding: images/gadang sumatera/d-254.png (deflated 0%)
#   adding: images/gadang sumatera/d-256.png (deflated 0%)
#   adding: images/gadang sumatera/d-257.png (deflated 0%)
#   adding: images/gadang sumatera/d-258.png (deflated 0%)
#   adding: images/gadang sumatera/d-260.png (deflated 0%)
#   adding: images/gadang sumatera/d-261.png (deflated 0%)
#   adding: images/gadang sumatera/d-262.png (deflated 1%)
#   adding: images/gadang sumatera/d-263.png (deflated 0%)
#   adding: images/gadang sumatera/d-264.png (deflated 0%)
#   adding: images/gadang sumatera/d-265.png (deflated 0%)
#   adding: images/gadang sumatera/d-267.png (deflated 0%)
#   adding: images/gadang sumatera/d-268.png (deflated 0%)
#   adding: images/gadang sumatera/d-269.png (deflated 0%)
#   adding: images/gadang sumatera/d-271.png (deflated 0%)
#   adding: images/gadang sumatera/d-272.png (deflated 0%)
#   adding: images/gadang sumatera/d-273.png (deflated 0%)
#   adding: images/gadang sumatera/d-274.png (deflated 1%)
#   adding: images/gadang sumatera/d-275.png (deflated 0%)
#   adding: images/gadang sumatera/d-276.png (deflated 0%)
#   adding: images/gadang sumatera/d-277.png (deflated 0%)
#   adding: images/gadang sumatera/d-278.png (deflated 0%)
#   adding: images/gadang sumatera/d-279.png (deflated 0%)
#   adding: images/gadang sumatera/d-280.png (deflated 0%)
#   adding: images/gadang sumatera/d-281.png (deflated 0%)
#   adding: images/gadang sumatera/d-282.png (deflated 0%)
#   adding: images/gadang sumatera/d-283.png (deflated 0%)
#   adding: images/gadang sumatera/d-284.png (deflated 0%)
#   adding: images/gadang sumatera/d-287.png (deflated 1%)
#   adding: images/gadang sumatera/d-288.png (deflated 0%)
#   adding: images/gadang sumatera/d-289.png (deflated 0%)
#   adding: images/gadang sumatera/d-28.png (deflated 0%)
#   adding: images/gadang sumatera/d-290.png (deflated 0%)
#   adding: images/gadang sumatera/d-292.png (deflated 0%)
#   adding: images/gadang sumatera/d-293.png (deflated 0%)
#   adding: images/gadang sumatera/d-294.png (deflated 0%)
#   adding: images/gadang sumatera/d-296.png (deflated 0%)
#   adding: images/gadang sumatera/d-297.png (deflated 1%)
#   adding: images/gadang sumatera/d-298.png (deflated 1%)
#   adding: images/gadang sumatera/d-299.png (deflated 0%)
#   adding: images/gadang sumatera/d-29.png (deflated 0%)
#   adding: images/gadang sumatera/d-2.png (deflated 0%)
#   adding: images/gadang sumatera/d-300.png (deflated 0%)
#   adding: images/gadang sumatera/d-302.png (deflated 0%)
#   adding: images/gadang sumatera/d-303.png (deflated 0%)
#   adding: images/gadang sumatera/d-304.png (deflated 0%)
#   adding: images/gadang sumatera/d-305.png (deflated 0%)
#   adding: images/gadang sumatera/d-306.png (deflated 0%)
#   adding: images/gadang sumatera/d-307.png (deflated 0%)
#   adding: images/gadang sumatera/d-308.png (deflated 0%)
#   adding: images/gadang sumatera/d-309.png (deflated 0%)
#   adding: images/gadang sumatera/d-311.png (deflated 0%)
#   adding: images/gadang sumatera/d-312.png (deflated 0%)
#   adding: images/gadang sumatera/d-314.png (deflated 0%)
#   adding: images/gadang sumatera/d-315.png (deflated 0%)
#   adding: images/gadang sumatera/d-317.png (deflated 0%)
#   adding: images/gadang sumatera/d-319.png (deflated 0%)
#   adding: images/gadang sumatera/d-321.png (deflated 0%)
#   adding: images/gadang sumatera/d-323.png (deflated 0%)
#   adding: images/gadang sumatera/d-324.png (deflated 0%)
#   adding: images/gadang sumatera/d-326.png (deflated 0%)
#   adding: images/gadang sumatera/d-327.png (deflated 0%)
#   adding: images/gadang sumatera/d-328.png (deflated 0%)
#   adding: images/gadang sumatera/d-329.png (deflated 0%)
#   adding: images/gadang sumatera/d-330.png (deflated 0%)
#   adding: images/gadang sumatera/d-331.png (deflated 0%)
#   adding: images/gadang sumatera/d-332.png (deflated 0%)
#   adding: images/gadang sumatera/d-336.png (deflated 0%)
#   adding: images/gadang sumatera/d-337.png (deflated 0%)
#   adding: images/gadang sumatera/d-338.png (deflated 1%)
#   adding: images/gadang sumatera/d-340.png (deflated 0%)
#   adding: images/gadang sumatera/d-341.png (deflated 0%)
#   adding: images/gadang sumatera/d-343.png (deflated 0%)
#   adding: images/gadang sumatera/d-344.png (deflated 0%)
#   adding: images/gadang sumatera/d-345.png (deflated 0%)
#   adding: images/gadang sumatera/d-346.png (deflated 0%)
#   adding: images/gadang sumatera/d-347.png (deflated 0%)
#   adding: images/gadang sumatera/d-348.png (deflated 0%)
#   adding: images/gadang sumatera/d-349.png (deflated 0%)
#   adding: images/gadang sumatera/d-34.png (deflated 0%)
#   adding: images/gadang sumatera/d-350.png (deflated 0%)
#   adding: images/gadang sumatera/d-351.png (deflated 0%)
#   adding: images/gadang sumatera/d-352.png (deflated 0%)
#   adding: images/gadang sumatera/d-353.png (deflated 0%)
#   adding: images/gadang sumatera/d-354.png (deflated 0%)
#   adding: images/gadang sumatera/d-355.png (deflated 0%)
#   adding: images/gadang sumatera/d-356.png (deflated 0%)
#   adding: images/gadang sumatera/d-357.png (deflated 0%)
#   adding: images/gadang sumatera/d-358.png (deflated 2%)
#   adding: images/gadang sumatera/d-35.png (deflated 0%)
#   adding: images/gadang sumatera/d-360.png (deflated 0%)
#   adding: images/gadang sumatera/d-361.png (deflated 4%)
#   adding: images/gadang sumatera/d-362.png (deflated 0%)
#   adding: images/gadang sumatera/d-363.png (deflated 2%)
#   adding: images/gadang sumatera/d-364.png (deflated 1%)
#   adding: images/gadang sumatera/d-365.png (deflated 0%)
#   adding: images/gadang sumatera/d-367.png (deflated 0%)
#   adding: images/gadang sumatera/d-368.png (deflated 0%)
#   adding: images/gadang sumatera/d-369.png (deflated 0%)
#   adding: images/gadang sumatera/d-36.png (deflated 0%)
#   adding: images/gadang sumatera/d-370.png (deflated 0%)
#   adding: images/gadang sumatera/d-371.png (deflated 0%)
#   adding: images/gadang sumatera/d-372.png (deflated 0%)
#   adding: images/gadang sumatera/d-373.png (deflated 0%)
#   adding: images/gadang sumatera/d-374.png (deflated 0%)
#   adding: images/gadang sumatera/d-376.png (deflated 0%)
#   adding: images/gadang sumatera/d-378.png (deflated 1%)
#   adding: images/gadang sumatera/d-380.png (deflated 0%)
#   adding: images/gadang sumatera/d-381.png (deflated 0%)
#   adding: images/gadang sumatera/d-382.png (deflated 0%)
#   adding: images/gadang sumatera/d-383.png (deflated 0%)
#   adding: images/gadang sumatera/d-384.png (deflated 0%)
#   adding: images/gadang sumatera/d-385.png (deflated 0%)
#   adding: images/gadang sumatera/d-386.png (deflated 0%)
#   adding: images/gadang sumatera/d-387.png (deflated 0%)
#   adding: images/gadang sumatera/d-390.png (deflated 0%)
#   adding: images/gadang sumatera/d-391.png (deflated 0%)
#   adding: images/gadang sumatera/d-392.png (deflated 0%)
#   adding: images/gadang sumatera/d-393.png (deflated 1%)
#   adding: images/gadang sumatera/d-394.png (deflated 0%)
#   adding: images/gadang sumatera/d-395.png (deflated 0%)
#   adding: images/gadang sumatera/d-397.png (deflated 0%)
#   adding: images/gadang sumatera/d-398.png (deflated 0%)
#   adding: images/gadang sumatera/d-399.png (deflated 0%)
#   adding: images/gadang sumatera/d-400.png (deflated 0%)
#   adding: images/gadang sumatera/d-401.png (deflated 1%)
#   adding: images/gadang sumatera/d-402.png (deflated 0%)
#   adding: images/gadang sumatera/d-403.png (deflated 0%)
#   adding: images/gadang sumatera/d-404.png (deflated 0%)
#   adding: images/gadang sumatera/d-405.png (deflated 0%)
#   adding: images/gadang sumatera/d-406.png (deflated 0%)
#   adding: images/gadang sumatera/d-408.png (deflated 0%)
#   adding: images/gadang sumatera/d-409.png (deflated 0%)
#   adding: images/gadang sumatera/d-410.png (deflated 0%)
#   adding: images/gadang sumatera/d-411.png (deflated 1%)
#   adding: images/gadang sumatera/d-412.png (deflated 0%)
#   adding: images/gadang sumatera/d-413.png (deflated 0%)
#   adding: images/gadang sumatera/d-414.png (deflated 0%)
#   adding: images/gadang sumatera/d-415.png (deflated 0%)
#   adding: images/gadang sumatera/d-416.png (deflated 0%)
#   adding: images/gadang sumatera/d-417.png (deflated 0%)
#   adding: images/gadang sumatera/d-418.png (deflated 3%)
#   adding: images/gadang sumatera/d-419.png (deflated 0%)
#   adding: images/gadang sumatera/d-420.png (deflated 0%)
#   adding: images/gadang sumatera/d-421.png (deflated 0%)
#   adding: images/gadang sumatera/d-422.png (deflated 0%)
#   adding: images/gadang sumatera/d-423.png (deflated 0%)
#   adding: images/gadang sumatera/d-424.png (deflated 0%)
#   adding: images/gadang sumatera/d-425.png (deflated 0%)
#   adding: images/gadang sumatera/d-426.png (deflated 0%)
#   adding: images/gadang sumatera/d-427.png (deflated 1%)
#   adding: images/gadang sumatera/d-428.png (deflated 5%)
#   adding: images/gadang sumatera/d-429.png (deflated 0%)
#   adding: images/gadang sumatera/d-430.png (deflated 0%)
#   adding: images/gadang sumatera/d-431.png (deflated 0%)
#   adding: images/gadang sumatera/d-432.png (deflated 0%)
#   adding: images/gadang sumatera/d-433.png (deflated 2%)
#   adding: images/gadang sumatera/d-434.png (deflated 0%)
#   adding: images/gadang sumatera/d-435.png (deflated 0%)
#   adding: images/gadang sumatera/d-436.png (deflated 1%)
#   adding: images/gadang sumatera/d-437.png (deflated 0%)
#   adding: images/gadang sumatera/d-438.png (deflated 0%)
#   adding: images/gadang sumatera/d-439.png (deflated 0%)
#   adding: images/gadang sumatera/d-43.png (deflated 0%)
#   adding: images/gadang sumatera/d-440.png (deflated 0%)
#   adding: images/gadang sumatera/d-441.png (deflated 0%)
#   adding: images/gadang sumatera/d-442.png (deflated 0%)
#   adding: images/gadang sumatera/d-443.png (deflated 0%)
#   adding: images/gadang sumatera/d-444.png (deflated 0%)
#   adding: images/gadang sumatera/d-445.png (deflated 0%)
#   adding: images/gadang sumatera/d-446.png (deflated 0%)
#   adding: images/gadang sumatera/d-447.png (deflated 0%)
#   adding: images/gadang sumatera/d-448.png (deflated 0%)
#   adding: images/gadang sumatera/d-449.png (deflated 0%)
#   adding: images/gadang sumatera/d-450.png (deflated 0%)
#   adding: images/gadang sumatera/d-451.png (stored 0%)
#   adding: images/gadang sumatera/d-452.png (deflated 0%)
#   adding: images/gadang sumatera/d-453.png (deflated 0%)
#   adding: images/gadang sumatera/d-454.png (deflated 0%)
#   adding: images/gadang sumatera/d-455.png (deflated 0%)
#   adding: images/gadang sumatera/d-456.png (deflated 0%)
#   adding: images/gadang sumatera/d-457.png (deflated 0%)
#   adding: images/gadang sumatera/d-458.png (deflated 5%)
#   adding: images/gadang sumatera/d-459.png (deflated 0%)
#   adding: images/gadang sumatera/d-460.png (deflated 10%)
#   adding: images/gadang sumatera/d-461.png (deflated 0%)
#   adding: images/gadang sumatera/d-462.png (deflated 0%)
#   adding: images/gadang sumatera/d-463.png (deflated 0%)
#   adding: images/gadang sumatera/d-464.png (deflated 0%)
#   adding: images/gadang sumatera/d-465.png (deflated 0%)
#   adding: images/gadang sumatera/d-466.png (deflated 0%)
#   adding: images/gadang sumatera/d-467.png (deflated 0%)
#   adding: images/gadang sumatera/d-468.png (deflated 0%)
#   adding: images/gadang sumatera/d-469.png (deflated 0%)
#   adding: images/gadang sumatera/d-470.png (deflated 0%)
#   adding: images/gadang sumatera/d-471.png (deflated 0%)
#   adding: images/gadang sumatera/d-472.png (deflated 0%)
#   adding: images/gadang sumatera/d-473.png (deflated 0%)
#   adding: images/gadang sumatera/d-474.png (deflated 6%)
#   adding: images/gadang sumatera/d-475.png (deflated 0%)
#   adding: images/gadang sumatera/d-477.png (deflated 0%)
#   adding: images/gadang sumatera/d-478.png (deflated 1%)
#   adding: images/gadang sumatera/d-479.png (deflated 0%)
#   adding: images/gadang sumatera/d-480.png (deflated 0%)
#   adding: images/gadang sumatera/d-481.png (deflated 0%)
#   adding: images/gadang sumatera/d-482.png (deflated 0%)
#   adding: images/gadang sumatera/d-483.png (deflated 0%)
#   adding: images/gadang sumatera/d-484.png (deflated 0%)
#   adding: images/gadang sumatera/d-485.png (deflated 0%)
#   adding: images/gadang sumatera/d-486.png (deflated 0%)
#   adding: images/gadang sumatera/d-487.png (deflated 2%)
#   adding: images/gadang sumatera/d-488.png (deflated 0%)
#   adding: images/gadang sumatera/d-489.png (deflated 0%)
#   adding: images/gadang sumatera/d-490.png (deflated 0%)
#   adding: images/gadang sumatera/d-492.png (deflated 0%)
#   adding: images/gadang sumatera/d-493.png (deflated 0%)
#   adding: images/gadang sumatera/d-494.png (deflated 0%)
#   adding: images/gadang sumatera/d-495.png (deflated 0%)
#   adding: images/gadang sumatera/d-496.png (deflated 0%)
#   adding: images/gadang sumatera/d-497.png (deflated 0%)
#   adding: images/gadang sumatera/d-498.png (deflated 0%)
#   adding: images/gadang sumatera/d-499.png (deflated 0%)
#   adding: images/gadang sumatera/d-4.png (deflated 0%)
#   adding: images/gadang sumatera/d-500.png (deflated 0%)
#   adding: images/gadang sumatera/d-501.png (deflated 0%)
#   adding: images/gadang sumatera/d-50.png (deflated 0%)
#   adding: images/gadang sumatera/d-51.png (deflated 0%)
#   adding: images/gadang sumatera/d-54.png (deflated 0%)
#   adding: images/gadang sumatera/d-55.png (deflated 1%)
#   adding: images/gadang sumatera/d-58.png (deflated 0%)
#   adding: images/gadang sumatera/d-60.png (deflated 0%)
#   adding: images/gadang sumatera/d-67.png (deflated 0%)
#   adding: images/gadang sumatera/d-68.png (deflated 0%)
#   adding: images/gadang sumatera/d-69.png (deflated 0%)
#   adding: images/gadang sumatera/d-71.png (deflated 0%)
#   adding: images/gadang sumatera/d-75.png (deflated 0%)
#   adding: images/gadang sumatera/d-76.png (deflated 1%)
#   adding: images/gadang sumatera/d-78.png (deflated 0%)
#   adding: images/gadang sumatera/d-84.png (deflated 0%)
#   adding: images/gadang sumatera/d-85.png (deflated 0%)
#   adding: images/gadang sumatera/d-94.png (deflated 0%)
#   adding: images/gadang sumatera/d-96.png (deflated 0%)
#   adding: images/gadang sumatera/d-98.png (deflated 0%)
#   adding: images/gadang sumatera/d-99.png (deflated 0%)
#   adding: images/gadang sumatera/g-101.png (deflated 0%)
#   adding: images/gadang sumatera/g-104.png (deflated 0%)
#   adding: images/gadang sumatera/g-105.png (stored 0%)
#   adding: images/gadang sumatera/g-106.png (deflated 0%)
#   adding: images/gadang sumatera/g-108.png (deflated 1%)
#   adding: images/gadang sumatera/g-109.png (stored 0%)
#   adding: images/gadang sumatera/g-10.png (deflated 3%)
#   adding: images/gadang sumatera/g-110.png (deflated 1%)
#   adding: images/gadang sumatera/g-111.png (stored 0%)
#   adding: images/gadang sumatera/g-112.png (deflated 5%)
#   adding: images/gadang sumatera/g-113.png (stored 0%)
#   adding: images/gadang sumatera/g-114.png (deflated 5%)
#   adding: images/gadang sumatera/g-116.png (deflated 4%)
#   adding: images/gadang sumatera/g-117.png (stored 0%)
#   adding: images/gadang sumatera/g-118.png (deflated 0%)
#   adding: images/gadang sumatera/g-120.png (deflated 0%)
#   adding: images/gadang sumatera/g-121.png (stored 0%)
#   adding: images/gadang sumatera/g-123.png (deflated 0%)
#   adding: images/gadang sumatera/g-125.png (deflated 6%)
#   adding: images/gadang sumatera/g-127.png (deflated 0%)
#   adding: images/gadang sumatera/g-128.png (stored 0%)
#   adding: images/gadang sumatera/g-129.png (deflated 0%)
#   adding: images/gadang sumatera/g-12.png (deflated 0%)
#   adding: images/gadang sumatera/g-131.png (stored 0%)
#   adding: images/gadang sumatera/g-132.png (deflated 1%)
#   adding: images/gadang sumatera/g-135.png (stored 0%)
#   adding: images/gadang sumatera/g-136.png (deflated 0%)
#   adding: images/gadang sumatera/g-137.png (stored 0%)
#   adding: images/gadang sumatera/g-138.png (deflated 0%)
#   adding: images/gadang sumatera/g-13.png (stored 0%)
#   adding: images/gadang sumatera/g-140.png (deflated 0%)
#   adding: images/gadang sumatera/g-142.png (deflated 4%)
#   adding: images/gadang sumatera/g-143.png (stored 0%)
#   adding: images/gadang sumatera/g-144.png (deflated 0%)
#   adding: images/gadang sumatera/g-146.png (deflated 4%)
#   adding: images/gadang sumatera/g-148.png (deflated 0%)
#   adding: images/gadang sumatera/g-14.png (deflated 0%)
#   adding: images/gadang sumatera/g-150.png (deflated 0%)
#   adding: images/gadang sumatera/g-152.png (deflated 0%)
#   adding: images/gadang sumatera/g-154.png (deflated 5%)
#   adding: images/gadang sumatera/g-155.png (deflated 1%)
#   adding: images/gadang sumatera/g-156.png (deflated 2%)
#   adding: images/gadang sumatera/g-158.png (deflated 1%)
#   adding: images/gadang sumatera/g-159.png (deflated 0%)
#   adding: images/gadang sumatera/g-15.png (stored 0%)
#   adding: images/gadang sumatera/g-160.png (stored 0%)
#   adding: images/gadang sumatera/g-161.png (deflated 0%)
#   adding: images/gadang sumatera/g-164.png (stored 0%)
#   adding: images/gadang sumatera/g-165.png (deflated 0%)
#   adding: images/gadang sumatera/g-167.png (deflated 0%)
#   adding: images/gadang sumatera/g-168.png (stored 0%)
#   adding: images/gadang sumatera/g-16.png (deflated 1%)
#   adding: images/gadang sumatera/g-171.png (deflated 0%)
#   adding: images/gadang sumatera/g-172.png (stored 0%)
#   adding: images/gadang sumatera/g-173.png (deflated 0%)
#   adding: images/gadang sumatera/g-174.png (stored 0%)
#   adding: images/gadang sumatera/g-175.png (deflated 1%)
#   adding: images/gadang sumatera/g-177.png (deflated 0%)
#   adding: images/gadang sumatera/g-178.png (deflated 0%)
#   adding: images/gadang sumatera/g-179.png (stored 0%)
#   adding: images/gadang sumatera/g-17.png (stored 0%)
#   adding: images/gadang sumatera/g-180.png (deflated 0%)
#   adding: images/gadang sumatera/g-181.png (stored 0%)
#   adding: images/gadang sumatera/g-182.png (deflated 0%)
#   adding: images/gadang sumatera/g-183.png (stored 0%)
#   adding: images/gadang sumatera/g-184.png (deflated 3%)
#   adding: images/gadang sumatera/g-185.png (stored 0%)
#   adding: images/gadang sumatera/g-186.png (deflated 0%)
#   adding: images/gadang sumatera/g-187.png (stored 0%)
#   adding: images/gadang sumatera/g-188.png (deflated 0%)
#   adding: images/gadang sumatera/g-189.png (stored 0%)
#   adding: images/gadang sumatera/g-18.png (deflated 0%)
#   adding: images/gadang sumatera/g-190.png (deflated 1%)
#   adding: images/gadang sumatera/g-192.png (deflated 1%)
#   adding: images/gadang sumatera/g-193.png (stored 0%)
#   adding: images/gadang sumatera/g-194.png (deflated 0%)
#   adding: images/gadang sumatera/g-195.png (stored 0%)
#   adding: images/gadang sumatera/g-196.png (deflated 0%)
#   adding: images/gadang sumatera/g-197.png (stored 0%)
#   adding: images/gadang sumatera/g-198.png (deflated 0%)
#   adding: images/gadang sumatera/g-201.png (stored 0%)
#   adding: images/gadang sumatera/g-202.png (deflated 0%)
#   adding: images/gadang sumatera/g-203.png (stored 0%)
#   adding: images/gadang sumatera/g-204.png (deflated 3%)
#   adding: images/gadang sumatera/g-207.png (stored 0%)
#   adding: images/gadang sumatera/g-208.png (deflated 1%)
#   adding: images/gadang sumatera/g-20.png (deflated 0%)
#   adding: images/gadang sumatera/g-210.png (deflated 1%)
#   adding: images/gadang sumatera/g-212.png (deflated 0%)
#   adding: images/gadang sumatera/g-214.png (deflated 0%)
#   adding: images/gadang sumatera/g-215.png (stored 0%)
#   adding: images/gadang sumatera/g-216.png (deflated 0%)
#   adding: images/gadang sumatera/g-218.png (deflated 1%)
#   adding: images/gadang sumatera/g-219.png (stored 0%)
#   adding: images/gadang sumatera/g-220.png (deflated 0%)
#   adding: images/gadang sumatera/g-221.png (stored 0%)
#   adding: images/gadang sumatera/g-222.png (deflated 0%)
#   adding: images/gadang sumatera/g-224.png (deflated 0%)
#   adding: images/gadang sumatera/g-225.png (stored 0%)
#   adding: images/gadang sumatera/g-227.png (stored 0%)
#   adding: images/gadang sumatera/g-229.png (deflated 0%)
#   adding: images/gadang sumatera/g-230.png (deflated 1%)
#   adding: images/gadang sumatera/g-231.png (deflated 0%)
#   adding: images/gadang sumatera/g-233.png (deflated 0%)
#   adding: images/gadang sumatera/g-234.png (stored 0%)
#   adding: images/gadang sumatera/g-235.png (deflated 0%)
#   adding: images/gadang sumatera/g-236.png (stored 0%)
#   adding: images/gadang sumatera/g-237.png (deflated 0%)
#   adding: images/gadang sumatera/g-239.png (deflated 0%)
#   adding: images/gadang sumatera/g-240.png (stored 0%)
#   adding: images/gadang sumatera/g-241.png (deflated 0%)
#   adding: images/gadang sumatera/g-244.png (stored 0%)
#   adding: images/gadang sumatera/g-245.png (deflated 0%)
#   adding: images/gadang sumatera/g-246.png (stored 0%)
#   adding: images/gadang sumatera/g-247.png (deflated 0%)
#   adding: images/gadang sumatera/g-24.png (deflated 0%)
#   adding: images/gadang sumatera/g-250.png (stored 0%)
#   adding: images/gadang sumatera/g-251.png (deflated 0%)
#   adding: images/gadang sumatera/g-253.png (deflated 0%)
#   adding: images/gadang sumatera/g-254.png (stored 0%)
#   adding: images/gadang sumatera/g-255.png (deflated 0%)
#   adding: images/gadang sumatera/g-256.png (stored 0%)
#   adding: images/gadang sumatera/g-257.png (deflated 0%)
#   adding: images/gadang sumatera/g-260.png (stored 0%)
#   adding: images/gadang sumatera/g-261.png (deflated 1%)
#   adding: images/gadang sumatera/g-263.png (deflated 1%)
#   adding: images/gadang sumatera/g-264.png (stored 0%)
#   adding: images/gadang sumatera/g-265.png (deflated 10%)
#   adding: images/gadang sumatera/g-267.png (deflated 0%)
#   adding: images/gadang sumatera/g-268.png (stored 0%)
#   adding: images/gadang sumatera/g-269.png (deflated 0%)
#   adding: images/gadang sumatera/g-26.png (deflated 0%)
#   adding: images/gadang sumatera/g-271.png (deflated 0%)
#   adding: images/gadang sumatera/g-272.png (stored 0%)
#   adding: images/gadang sumatera/g-273.png (deflated 0%)
#   adding: images/gadang sumatera/g-274.png (stored 0%)
#   adding: images/gadang sumatera/g-275.png (deflated 1%)
#   adding: images/gadang sumatera/g-276.png (stored 0%)
#   adding: images/gadang sumatera/g-277.png (deflated 1%)
#   adding: images/gadang sumatera/g-278.png (stored 0%)
#   adding: images/gadang sumatera/g-279.png (deflated 0%)
#   adding: images/gadang sumatera/g-27.png (stored 0%)
#   adding: images/gadang sumatera/g-280.png (deflated 0%)
#   adding: images/gadang sumatera/g-283.png (stored 0%)
#   adding: images/gadang sumatera/g-284.png (deflated 0%)
#   adding: images/gadang sumatera/g-285.png (stored 0%)
#   adding: images/gadang sumatera/g-286.png (deflated 1%)
#   adding: images/gadang sumatera/g-287.png (stored 0%)
#   adding: images/gadang sumatera/g-288.png (deflated 0%)
#   adding: images/gadang sumatera/g-289.png (stored 0%)
#   adding: images/gadang sumatera/g-290.png (deflated 2%)
#   adding: images/gadang sumatera/g-292.png (deflated 0%)
#   adding: images/gadang sumatera/g-293.png (deflated 0%)
#   adding: images/gadang sumatera/g-295.png (deflated 1%)
#   adding: images/gadang sumatera/g-297.png (deflated 1%)
#   adding: images/gadang sumatera/g-299.png (deflated 2%)
#   adding: images/gadang sumatera/g-29.png (deflated 0%)
#   adding: images/gadang sumatera/g-300.png (deflated 2%)
#   adding: images/gadang sumatera/g-301.png (deflated 0%)
#   adding: images/gadang sumatera/g-302.png (stored 0%)
#   adding: images/gadang sumatera/g-303.png (deflated 0%)
#   adding: images/gadang sumatera/g-304.png (stored 0%)
#   adding: images/gadang sumatera/g-305.png (deflated 0%)
#   adding: images/gadang sumatera/g-307.png (deflated 0%)
#   adding: images/gadang sumatera/g-308.png (stored 0%)
#   adding: images/gadang sumatera/g-309.png (deflated 0%)
#   adding: images/gadang sumatera/g-310.png (stored 0%)
#   adding: images/gadang sumatera/g-311.png (deflated 0%)
#   adding: images/gadang sumatera/g-312.png (stored 0%)
#   adding: images/gadang sumatera/g-313.png (deflated 0%)
#   adding: images/gadang sumatera/g-315.png (deflated 0%)
#   adding: images/gadang sumatera/g-317.png (deflated 0%)
#   adding: images/gadang sumatera/g-318.png (stored 0%)
#   adding: images/gadang sumatera/g-319.png (deflated 0%)
#   adding: images/gadang sumatera/g-321.png (deflated 0%)
#   adding: images/gadang sumatera/g-322.png (stored 0%)
#   adding: images/gadang sumatera/g-323.png (deflated 1%)
#   adding: images/gadang sumatera/g-324.png (deflated 0%)
#   adding: images/gadang sumatera/g-325.png (stored 0%)
#   adding: images/gadang sumatera/g-326.png (deflated 0%)
#   adding: images/gadang sumatera/g-327.png (stored 0%)
#   adding: images/gadang sumatera/g-328.png (deflated 0%)
#   adding: images/gadang sumatera/g-329.png (stored 0%)
#   adding: images/gadang sumatera/g-32.png (stored 0%)
#   adding: images/gadang sumatera/g-330.png (deflated 0%)
#   adding: images/gadang sumatera/g-331.png (stored 0%)
#   adding: images/gadang sumatera/g-332.png (deflated 1%)
#   adding: images/gadang sumatera/g-334.png (deflated 0%)
#   adding: images/gadang sumatera/g-335.png (stored 0%)
#   adding: images/gadang sumatera/g-336.png (deflated 0%)
#   adding: images/gadang sumatera/g-338.png (deflated 0%)
#   adding: images/gadang sumatera/g-339.png (stored 0%)
#   adding: images/gadang sumatera/g-33.png (deflated 1%)
#   adding: images/gadang sumatera/g-340.png (deflated 0%)
#   adding: images/gadang sumatera/g-342.png (deflated 2%)
#   adding: images/gadang sumatera/g-343.png (stored 0%)
#   adding: images/gadang sumatera/g-344.png (deflated 0%)
#   adding: images/gadang sumatera/g-345.png (stored 0%)
#   adding: images/gadang sumatera/g-346.png (deflated 1%)
#   adding: images/gadang sumatera/g-347.png (stored 0%)
#   adding: images/gadang sumatera/g-348.png (deflated 0%)
#   adding: images/gadang sumatera/g-349.png (stored 0%)
#   adding: images/gadang sumatera/g-350.png (deflated 0%)
#   adding: images/gadang sumatera/g-351.png (stored 0%)
#   adding: images/gadang sumatera/g-352.png (deflated 1%)
#   adding: images/gadang sumatera/g-353.png (deflated 1%)
#   adding: images/gadang sumatera/g-354.png (stored 0%)
#   adding: images/gadang sumatera/g-355.png (deflated 0%)
#   adding: images/gadang sumatera/g-357.png (deflated 0%)
#   adding: images/gadang sumatera/g-358.png (deflated 0%)
#   adding: images/gadang sumatera/g-359.png (deflated 0%)
#   adding: images/gadang sumatera/g-35.png (deflated 0%)
#   adding: images/gadang sumatera/g-360.png (stored 0%)
#   adding: images/gadang sumatera/g-361.png (deflated 0%)
#   adding: images/gadang sumatera/g-362.png (stored 0%)
#   adding: images/gadang sumatera/g-363.png (deflated 0%)
#   adding: images/gadang sumatera/g-364.png (stored 0%)
#   adding: images/gadang sumatera/g-365.png (deflated 1%)
#   adding: images/gadang sumatera/g-366.png (stored 0%)
#   adding: images/gadang sumatera/g-367.png (deflated 0%)
#   adding: images/gadang sumatera/g-368.png (stored 0%)
#   adding: images/gadang sumatera/g-369.png (deflated 1%)
#   adding: images/gadang sumatera/g-36.png (stored 0%)
#   adding: images/gadang sumatera/g-371.png (deflated 0%)
#   adding: images/gadang sumatera/g-372.png (stored 0%)
#   adding: images/gadang sumatera/g-373.png (deflated 1%)
#   adding: images/gadang sumatera/g-375.png (deflated 1%)
#   adding: images/gadang sumatera/g-376.png (deflated 0%)
#   adding: images/gadang sumatera/g-377.png (stored 0%)
#   adding: images/gadang sumatera/g-378.png (deflated 0%)
#   adding: images/gadang sumatera/g-379.png (stored 0%)
#   adding: images/gadang sumatera/g-37.png (deflated 9%)
#   adding: images/gadang sumatera/g-380.png (deflated 0%)
#   adding: images/gadang sumatera/g-381.png (stored 0%)
#   adding: images/gadang sumatera/g-382.png (deflated 1%)
#   adding: images/gadang sumatera/g-383.png (stored 0%)
#   adding: images/gadang sumatera/g-384.png (deflated 0%)
#   adding: images/gadang sumatera/g-385.png (stored 0%)
#   adding: images/gadang sumatera/g-386.png (deflated 0%)
#   adding: images/gadang sumatera/g-388.png (deflated 0%)
#   adding: images/gadang sumatera/g-389.png (stored 0%)
#   adding: images/gadang sumatera/g-390.png (deflated 0%)
#   adding: images/gadang sumatera/g-392.png (deflated 0%)
#   adding: images/gadang sumatera/g-394.png (deflated 0%)
#   adding: images/gadang sumatera/g-395.png (stored 0%)
#   adding: images/gadang sumatera/g-397.png (stored 0%)
#   adding: images/gadang sumatera/g-398.png (deflated 0%)
#   adding: images/gadang sumatera/g-399.png (stored 0%)
#   adding: images/gadang sumatera/g-39.png (deflated 0%)
#   adding: images/gadang sumatera/g-3.png (deflated 0%)
#   adding: images/gadang sumatera/g-400.png (deflated 0%)
#   adding: images/gadang sumatera/g-401.png (stored 0%)
#   adding: images/gadang sumatera/g-402.png (deflated 0%)
#   adding: images/gadang sumatera/g-404.png (deflated 1%)
#   adding: images/gadang sumatera/g-405.png (stored 0%)
#   adding: images/gadang sumatera/g-406.png (deflated 0%)
#   adding: images/gadang sumatera/g-408.png (deflated 0%)
#   adding: images/gadang sumatera/g-409.png (stored 0%)
#   adding: images/gadang sumatera/g-410.png (deflated 0%)
#   adding: images/gadang sumatera/g-411.png (stored 0%)
#   adding: images/gadang sumatera/g-412.png (deflated 0%)
#   adding: images/gadang sumatera/g-414.png (deflated 5%)
#   adding: images/gadang sumatera/g-415.png (stored 0%)
#   adding: images/gadang sumatera/g-416.png (deflated 2%)
#   adding: images/gadang sumatera/g-417.png (stored 0%)
#   adding: images/gadang sumatera/g-419.png (stored 0%)
#   adding: images/gadang sumatera/g-41.png (deflated 0%)
#   adding: images/gadang sumatera/g-420.png (deflated 0%)
#   adding: images/gadang sumatera/g-422.png (deflated 0%)
#   adding: images/gadang sumatera/g-424.png (deflated 0%)
#   adding: images/gadang sumatera/g-425.png (deflated 1%)
#   adding: images/gadang sumatera/g-426.png (stored 0%)
#   adding: images/gadang sumatera/g-427.png (deflated 0%)
#   adding: images/gadang sumatera/g-428.png (stored 0%)
#   adding: images/gadang sumatera/g-42.png (stored 0%)
#   adding: images/gadang sumatera/g-430.png (deflated 2%)
#   adding: images/gadang sumatera/g-431.png (deflated 4%)
#   adding: images/gadang sumatera/g-432.png (stored 0%)
#   adding: images/gadang sumatera/g-433.png (deflated 0%)
#   adding: images/gadang sumatera/g-434.png (stored 0%)
#   adding: images/gadang sumatera/g-435.png (deflated 0%)
#   adding: images/gadang sumatera/g-437.png (deflated 1%)
#   adding: images/gadang sumatera/g-438.png (stored 0%)
#   adding: images/gadang sumatera/g-441.png (deflated 0%)
#   adding: images/gadang sumatera/g-443.png (deflated 0%)
#   adding: images/gadang sumatera/g-445.png (deflated 3%)
#   adding: images/gadang sumatera/g-446.png (stored 0%)
#   adding: images/gadang sumatera/g-447.png (deflated 0%)
#   adding: images/gadang sumatera/g-449.png (deflated 0%)
#   adding: images/gadang sumatera/g-450.png (stored 0%)
#   adding: images/gadang sumatera/g-451.png (deflated 0%)
#   adding: images/gadang sumatera/g-453.png (deflated 0%)
#   adding: images/gadang sumatera/g-455.png (deflated 0%)
#   adding: images/gadang sumatera/g-456.png (deflated 0%)
#   adding: images/gadang sumatera/g-457.png (stored 0%)
#   adding: images/gadang sumatera/g-458.png (deflated 3%)
#   adding: images/gadang sumatera/g-459.png (stored 0%)
#   adding: images/gadang sumatera/g-45.png (deflated 0%)
#   adding: images/gadang sumatera/g-460.png (deflated 0%)
#   adding: images/gadang sumatera/g-463.png (stored 0%)
#   adding: images/gadang sumatera/g-464.png (deflated 0%)
#   adding: images/gadang sumatera/g-465.png (stored 0%)
#   adding: images/gadang sumatera/g-466.png (deflated 0%)
#   adding: images/gadang sumatera/g-467.png (stored 0%)
#   adding: images/gadang sumatera/g-468.png (deflated 0%)
#   adding: images/gadang sumatera/g-469.png (deflated 0%)
#   adding: images/gadang sumatera/g-46.png (stored 0%)
#   adding: images/gadang sumatera/g-471.png (deflated 0%)
#   adding: images/gadang sumatera/g-472.png (stored 0%)
#   adding: images/gadang sumatera/g-473.png (deflated 0%)
#   adding: images/gadang sumatera/g-474.png (stored 0%)
#   adding: images/gadang sumatera/g-475.png (deflated 0%)
#   adding: images/gadang sumatera/g-476.png (stored 0%)
#   adding: images/gadang sumatera/g-478.png (stored 0%)
#   adding: images/gadang sumatera/g-479.png (stored 0%)
#   adding: images/gadang sumatera/g-47.png (deflated 0%)
#   adding: images/gadang sumatera/g-480.png (deflated 0%)
#   adding: images/gadang sumatera/g-481.png (stored 0%)
#   adding: images/gadang sumatera/g-482.png (deflated 0%)
#   adding: images/gadang sumatera/g-483.png (stored 0%)
#   adding: images/gadang sumatera/g-486.png (deflated 0%)
#   adding: images/gadang sumatera/g-487.png (stored 0%)
#   adding: images/gadang sumatera/g-488.png (deflated 0%)
#   adding: images/gadang sumatera/g-489.png (stored 0%)
#   adding: images/gadang sumatera/g-490.png (deflated 0%)
#   adding: images/gadang sumatera/g-491.png (stored 0%)
#   adding: images/gadang sumatera/g-494.png (deflated 0%)
#   adding: images/gadang sumatera/g-495.png (stored 0%)
#   adding: images/gadang sumatera/g-496.png (deflated 0%)
#   adding: images/gadang sumatera/g-498.png (deflated 0%)
#   adding: images/gadang sumatera/g-499.png (stored 0%)
#   adding: images/gadang sumatera/g-49.png (deflated 0%)
#   adding: images/gadang sumatera/g-500.png (deflated 6%)
#   adding: images/gadang sumatera/g-501.png (stored 0%)
#   adding: images/gadang sumatera/g-502.png (deflated 5%)
#   adding: images/gadang sumatera/g-503.png (stored 0%)
#   adding: images/gadang sumatera/g-504.png (deflated 0%)
#   adding: images/gadang sumatera/g-506.png (deflated 5%)
#   adding: images/gadang sumatera/g-508.png (deflated 0%)
#   adding: images/gadang sumatera/g-509.png (stored 0%)
#   adding: images/gadang sumatera/g-50.png (stored 0%)
#   adding: images/gadang sumatera/g-511.png (stored 0%)
#   adding: images/gadang sumatera/g-512.png (deflated 1%)
#   adding: images/gadang sumatera/g-514.png (deflated 1%)
#   adding: images/gadang sumatera/g-516.png (deflated 3%)
#   adding: images/gadang sumatera/g-517.png (stored 0%)
#   adding: images/gadang sumatera/g-518.png (deflated 0%)
#   adding: images/gadang sumatera/g-51.png (deflated 0%)
#   adding: images/gadang sumatera/g-520.png (deflated 1%)
#   adding: images/gadang sumatera/g-522.png (deflated 0%)
#   adding: images/gadang sumatera/g-523.png (stored 0%)
#   adding: images/gadang sumatera/g-524.png (deflated 0%)
#   adding: images/gadang sumatera/g-525.png (deflated 0%)
#   adding: images/gadang sumatera/g-527.png (deflated 0%)
#   adding: images/gadang sumatera/g-530.png (deflated 0%)
#   adding: images/gadang sumatera/g-532.png (deflated 1%)
#   adding: images/gadang sumatera/g-533.png (deflated 6%)
#   adding: images/gadang sumatera/g-534.png (stored 0%)
#   adding: images/gadang sumatera/g-535.png (deflated 0%)
#   adding: images/gadang sumatera/g-537.png (deflated 0%)
#   adding: images/gadang sumatera/g-538.png (stored 0%)
#   adding: images/gadang sumatera/g-539.png (deflated 0%)
#   adding: images/gadang sumatera/g-53.png (stored 0%)
#   adding: images/gadang sumatera/g-540.png (stored 0%)
#   adding: images/gadang sumatera/g-541.png (deflated 0%)
#   adding: images/gadang sumatera/g-543.png (deflated 0%)
#   adding: images/gadang sumatera/g-545.png (deflated 0%)
#   adding: images/gadang sumatera/g-549.png (deflated 0%)
#   adding: images/gadang sumatera/g-550.png (stored 0%)
#   adding: images/gadang sumatera/g-551.png (deflated 1%)
#   adding: images/gadang sumatera/g-552.png (stored 0%)
#   adding: images/gadang sumatera/g-554.png (deflated 0%)
#   adding: images/gadang sumatera/g-556.png (deflated 0%)
#   adding: images/gadang sumatera/g-557.png (stored 0%)
#   adding: images/gadang sumatera/g-558.png (deflated 0%)
#   adding: images/gadang sumatera/g-560.png (stored 0%)
#   adding: images/gadang sumatera/g-561.png (stored 0%)
#   adding: images/gadang sumatera/g-562.png (stored 0%)
#   adding: images/gadang sumatera/g-563.png (stored 0%)
#   adding: images/gadang sumatera/g-564.png (stored 0%)
#   adding: images/gadang sumatera/g-566.png (deflated 0%)
#   adding: images/gadang sumatera/g-568.png (deflated 0%)
#   adding: images/gadang sumatera/g-569.png (stored 0%)
#   adding: images/gadang sumatera/g-56.png (deflated 0%)
#   adding: images/gadang sumatera/g-570.png (deflated 0%)
#   adding: images/gadang sumatera/g-571.png (deflated 0%)
#   adding: images/gadang sumatera/g-572.png (deflated 0%)
#   adding: images/gadang sumatera/g-573.png (deflated 0%)
#   adding: images/gadang sumatera/g-574.png (deflated 0%)
#   adding: images/gadang sumatera/g-575.png (deflated 0%)
#   adding: images/gadang sumatera/g-576.png (stored 0%)
#   adding: images/gadang sumatera/g-581.png (deflated 0%)
#   adding: images/gadang sumatera/g-583.png (deflated 0%)
#   adding: images/gadang sumatera/g-585.png (deflated 0%)
#   adding: images/gadang sumatera/g-588.png (stored 0%)
#   adding: images/gadang sumatera/g-589.png (deflated 0%)
#   adding: images/gadang sumatera/g-58.png (deflated 0%)
#   adding: images/gadang sumatera/g-590.png (stored 0%)
#   adding: images/gadang sumatera/g-592.png (stored 0%)
#   adding: images/gadang sumatera/g-594.png (stored 0%)
#   adding: images/gadang sumatera/g-596.png (deflated 1%)
#   adding: images/gadang sumatera/g-597.png (deflated 0%)
#   adding: images/gadang sumatera/g-599.png (deflated 1%)
#   adding: images/gadang sumatera/g-5.png (deflated 0%)
#   adding: images/gadang sumatera/g-600.png (stored 0%)
#   adding: images/gadang sumatera/g-603.png (deflated 0%)
#   adding: images/gadang sumatera/g-605.png (deflated 0%)
#   adding: images/gadang sumatera/g-607.png (deflated 0%)
#   adding: images/gadang sumatera/g-609.png (deflated 0%)
#   adding: images/gadang sumatera/g-611.png (deflated 0%)
#   adding: images/gadang sumatera/g-613.png (deflated 0%)
#   adding: images/gadang sumatera/g-614.png (stored 0%)
#   adding: images/gadang sumatera/g-617.png (deflated 0%)
#   adding: images/gadang sumatera/g-619.png (deflated 2%)
#   adding: images/gadang sumatera/g-621.png (deflated 0%)
#   adding: images/gadang sumatera/g-622.png (deflated 0%)
#   adding: images/gadang sumatera/g-623.png (stored 0%)
#   adding: images/gadang sumatera/g-624.png (deflated 1%)
#   adding: images/gadang sumatera/g-626.png (deflated 0%)
#   adding: images/gadang sumatera/g-627.png (stored 0%)
#   adding: images/gadang sumatera/g-62.png (deflated 0%)
#   adding: images/gadang sumatera/g-632.png (deflated 0%)
#   adding: images/gadang sumatera/g-633.png (stored 0%)
#   adding: images/gadang sumatera/g-634.png (deflated 0%)
#   adding: images/gadang sumatera/g-635.png (stored 0%)
#   adding: images/gadang sumatera/g-636.png (deflated 0%)
#   adding: images/gadang sumatera/g-637.png (stored 0%)
#   adding: images/gadang sumatera/g-638.png (deflated 0%)
#   adding: images/gadang sumatera/g-63.png (stored 0%)
#   adding: images/gadang sumatera/g-640.png (deflated 0%)
#   adding: images/gadang sumatera/g-641.png (stored 0%)
#   adding: images/gadang sumatera/g-642.png (deflated 0%)
#   adding: images/gadang sumatera/g-643.png (stored 0%)
#   adding: images/gadang sumatera/g-644.png (deflated 0%)
#   adding: images/gadang sumatera/g-645.png (stored 0%)
#   adding: images/gadang sumatera/g-646.png (deflated 0%)
#   adding: images/gadang sumatera/g-648.png (stored 0%)
#   adding: images/gadang sumatera/g-649.png (deflated 0%)
#   adding: images/gadang sumatera/g-64.png (deflated 0%)
#   adding: images/gadang sumatera/g-650.png (stored 0%)
#   adding: images/gadang sumatera/g-651.png (deflated 0%)
#   adding: images/gadang sumatera/g-652.png (stored 0%)
#   adding: images/gadang sumatera/g-653.png (deflated 0%)
#   adding: images/gadang sumatera/g-654.png (stored 0%)
#   adding: images/gadang sumatera/g-655.png (deflated 2%)
#   adding: images/gadang sumatera/g-657.png (deflated 0%)
#   adding: images/gadang sumatera/g-658.png (stored 0%)
#   adding: images/gadang sumatera/g-659.png (deflated 0%)
#   adding: images/gadang sumatera/g-65.png (stored 0%)
#   adding: images/gadang sumatera/g-661.png (deflated 0%)
#   adding: images/gadang sumatera/g-662.png (deflated 0%)
#   adding: images/gadang sumatera/g-663.png (stored 0%)
#   adding: images/gadang sumatera/g-665.png (stored 0%)
#   adding: images/gadang sumatera/g-667.png (stored 0%)
#   adding: images/gadang sumatera/g-668.png (deflated 0%)
#   adding: images/gadang sumatera/g-669.png (stored 0%)
# ...
#   adding: images/Rumah adat gadang sumatera/g-608.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-60.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-611.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-615.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-616.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-617.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-61.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-621.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-623.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-626.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-627.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-629.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-62.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-630.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-631.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-633.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-634.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-636.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-637.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-639.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-63.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-640.png (deflated 1%)
#   adding: images/Rumah adat gadang sumatera/g-642.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-644.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-645.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-646.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-647.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-648.png (deflated 5%)
#   adding: images/Rumah adat gadang sumatera/g-64.png (deflated 1%)
#   adding: images/Rumah adat gadang sumatera/g-650.png (deflated 1%)
#   adding: images/Rumah adat gadang sumatera/g-652.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-653.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-654.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-655.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-657.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-658.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-65.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-660.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-661.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-662.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-663.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-664.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-665.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-666.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-667.png (deflated 2%)
#   adding: images/Rumah adat gadang sumatera/g-668.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-669.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-670.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-671.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-672.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-673.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-674.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-675.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-677.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-678.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-679.png (deflated 2%)
#   adding: images/Rumah adat gadang sumatera/g-67.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-681.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-682.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-683.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-684.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-685.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-686.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-687.png (deflated 1%)
#   adding: images/Rumah adat gadang sumatera/g-689.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-68.png (deflated 1%)
#   adding: images/Rumah adat gadang sumatera/g-691.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-693.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-694.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-696.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-697.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-698.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-699.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-700.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-701.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-702.png (deflated 1%)
#   adding: images/Rumah adat gadang sumatera/g-703.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-704.png (deflated 3%)
#   adding: images/Rumah adat gadang sumatera/g-706.png (deflated 1%)
#   adding: images/Rumah adat gadang sumatera/g-707.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-708.png (deflated 4%)
#   adding: images/Rumah adat gadang sumatera/g-709.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-70.png (deflated 1%)
#   adding: images/Rumah adat gadang sumatera/g-710.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-712.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-714.png (deflated 1%)
#   adding: images/Rumah adat gadang sumatera/g-716.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-717.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-718.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-71.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-720.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-721.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-722.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-723.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-724.png (deflated 6%)
#   adding: images/Rumah adat gadang sumatera/g-725.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-727.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-728.png (deflated 1%)
#   adding: images/Rumah adat gadang sumatera/g-72.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-730.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-731.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-732.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-733.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-734.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-735.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-737.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-73.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-741.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-742.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-744.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-745.png (deflated 1%)
#   adding: images/Rumah adat gadang sumatera/g-746.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-747.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-748.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-749.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-74.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-751.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-752.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-754.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-756.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-757.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-758.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-759.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-762.png (deflated 1%)
#   adding: images/Rumah adat gadang sumatera/g-763.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-764.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-766.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-767.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-768.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-76.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-770.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-771.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-772.png (deflated 1%)
#   adding: images/Rumah adat gadang sumatera/g-773.png (deflated 1%)
#   adding: images/Rumah adat gadang sumatera/g-774.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-775.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-777.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-781.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-782.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-783.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-784.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-785.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-786.png (deflated 1%)
#   adding: images/Rumah adat gadang sumatera/g-788.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-789.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-78.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-790.png (deflated 1%)
#   adding: images/Rumah adat gadang sumatera/g-791.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-792.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-793.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-794.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-796.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-797.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-798.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-799.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-800.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-801.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-802.png (deflated 1%)
#   adding: images/Rumah adat gadang sumatera/g-803.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-804.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-805.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-806.png (deflated 1%)
#   adding: images/Rumah adat gadang sumatera/g-80.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-810.png (deflated 1%)
#   adding: images/Rumah adat gadang sumatera/g-811.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-812.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-813.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-814.png (deflated 5%)
#   adding: images/Rumah adat gadang sumatera/g-816.png (deflated 2%)
#   adding: images/Rumah adat gadang sumatera/g-818.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-819.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-81.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-820.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-821.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-823.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-824.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-826.png (deflated 10%)
#   adding: images/Rumah adat gadang sumatera/g-827.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-828.png (deflated 1%)
#   adding: images/Rumah adat gadang sumatera/g-829.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-82.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-830.png (deflated 7%)
#   adding: images/Rumah adat gadang sumatera/g-831.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-832.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-834.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-835.png (deflated 1%)
#   adding: images/Rumah adat gadang sumatera/g-837.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-839.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-83.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-841.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-842.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-843.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-844.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-845.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-846.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-847.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-848.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-86.png (deflated 1%)
#   adding: images/Rumah adat gadang sumatera/g-87.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-88.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-90.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-91.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-92.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-93.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-95.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-96.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/g-97.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-98.png (deflated 2%)
#   adding: images/Rumah adat gadang sumatera/g-99.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/g-9.png (stored 0%)
#   adding: images/Rumah adat gadang sumatera/y-10.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/y-13.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/y-14.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/y-15.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/y-17.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/y-18.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/y-20.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/y-21.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/y-23.png (deflated 1%)
#   adding: images/Rumah adat gadang sumatera/y-27.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/y-28.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/y-31.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/y-34.png (deflated 1%)
#   adding: images/Rumah adat gadang sumatera/y-35.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/y-37.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/y-38.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/y-5.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/y-7.png (deflated 0%)
#   adding: images/Rumah adat gadang sumatera/y-8.png (deflated 0%)
#   adding: images/Rumah adat gadang/y-14.png (deflated 0%)
#   adding: images/Rumah adat gadang/y-16.png (deflated 0%)
#   adding: images/Rumah adat gadang/y-27.png (deflated 0%)
#   adding: images/Rumah adat gadang/y-29.png (deflated 1%)
#   adding: images/Rumah adat gadang/y-37.png (deflated 0%)
#   adding: images/Rumah adat gadang/y-38.png (deflated 0%)
#   adding: images/Rumah adat gadang/y-47.png (deflated 0%)
#   adding: images/Rumah adat gadang/y-48.png (deflated 0%)
#   adding: images/Rumah adat gadang/y-5.png (deflated 0%)
#   adding: images/Rumah adat gadang/y-7.png (deflated 1%)

# %%
from google.colab import files
files.download('images.zip')

# %%
# !cp images.zip /path/to/directory/images.zip
